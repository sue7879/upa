# %%
import pandas as pd
import numpy as np


u7=pd.read_csv("UPA2007.csv")
u8=pd.read_csv("UPA2008.csv")
u9=pd.read_csv("UPA2009.csv")
u10=pd.read_csv("UPA2010.csv")
u11=pd.read_csv("UPA2011.csv")
u12=pd.read_csv("UPA2012.csv")
u13=pd.read_csv("UPA2013.csv")
u14=pd.read_csv("UPA2014.csv")
u15=pd.read_csv("UPA2015.csv")
u16=pd.read_csv("UPA2016.csv")
u17=pd.read_csv("UPA2017.csv")
u18=pd.read_csv("UPA2018.csv")

u=[u7,u8,u9,u10,u11,u12,u13,u14,u15,u16,u17,u18]

# %%
#중복되는 열 삭제과정  26열-> 14열
newu8=u8.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu9=u9.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu10=u10.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu11=u11.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu12=u12.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu13=u13.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu14=u14.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu15=u15.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu16=u16.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu17=u17.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]
newu18=u18.iloc[:,[1,3,4,5,6,7,8,9,10,15,16,17,18,19]]

newu18.columns
# Out:
# Index(['호출부호', '입항횟수', '입출항일시', '시설명', 'BLNO', '업체명', '수출입구분', '적하항', '양하항',
#        '품목코드', '품명', '중량톤', '용적톤', '하역업체명'],
#       dtype='object')

# %%
newu18['입항횟수'].describe()
#입항횟수 통계요약

# %%
aa18=newu18[newu18['입항횟수']>=7]
aa18
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
# Out:
#         호출부호  입항횟수                   입출항일시             시설명              BLNO  \
# 1      S6BV5    14  2018-01-01 03:35:00 AM           정일컨부두        0057X37179
# 21     S6BV5    14  2018-01-01 03:35:00 AM           정일컨부두        0057X39366
# 22     S6BV5    14  2018-01-01 03:35:00 AM           정일컨부두        0057X37180
# 25     S6BV5    14  2018-01-01 03:35:00 AM           정일컨부두        0057X37178
# 28     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두     SSUI138ANZ050
# 30     DSQC6    29  2018-01-01 09:00:00 AM           정일2부두       SHORSHC1737
# 36     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두     SSUI138ANZ060
# 38     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두     SSUI138ANZ020
# 39     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두    SSUI138ANZ070B
# 43     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두     SSUI138ANZ030
# 46     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두    SSUI138ANZ040A
# 49     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두    SSUI138ANZ040C
# 50     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두    SSUI138ANZ040D
# 51     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두    SSUI138ANZ070A
# 52     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두    SSUI138ANZ040B
# 53     VRDL8     7  2018-01-01 11:00:00 AM           정일2부두     SSUI138ANZ010
# 54     D5NP9    15  2018-01-01 12:00:00 PM            가스부두       SHUYVTS1801
# 55     3ENL7    17  2018-01-01 12:00:00 PM            가스부두            KM2343
# 57     3FBS2    41  2018-01-01 12:35:00 PM        SK1부두 12      BD2017V23301
# 58     3FBS2    41  2018-01-01 12:35:00 PM        SK1부두 12      BD2017V23302
# 63     A8SP5    10  2018-01-01 04:00:00 PM           유화1부두           GCW0118
# 75     3FUK4     9  2018-01-01 10:00:00 PM           SK8부두   SJSS20171236001
# 78     DSQF5    26  2018-01-02 02:00:00 AM        S-OIL3부두       SHSKSHP1801
# 79      D7CD     8  2018-01-02 02:30:00 AM  정일스톨트헤븐울산신항4부두    TEM17016USDG02
# 80      D7CD     8  2018-01-02 02:30:00 AM  정일스톨트헤븐울산신항4부두    TEM17016USDG01
# 81     BLAU3     8  2018-01-02 04:00:00 AM        S-OIL1부두           XS51801
# 84     DSPY2    29  2018-01-02 07:00:00 AM        SK2부두 01        BL20171231
# 86     3FGZ7     7  2018-01-02 08:30:00 AM           UTT부두          HHV1718A
# 87     3FGZ7     7  2018-01-02 08:30:00 AM           정일2부두          HHV1718B
# 99     3FYQ7     9  2018-01-02 01:55:00 PM        SK1부두 11        SSKKT18011
# ...      ...   ...                     ...             ...               ...
# 22037   D7SG    13  2018-12-30 10:00:00 PM      신항컨테이너부두02    KMTCUSN2102947
# 22038   D7SG    13  2018-12-30 10:00:00 PM      신항컨테이너부두02    KMTCUSN2117480
# 22039   D7SG    13  2018-12-30 10:00:00 PM      신항컨테이너부두02   KMTCUSN2102947B
# 22040   D7SG    13  2018-12-30 10:00:00 PM      신항컨테이너부두03   HDMUULJT4853775
# 22041   D7SG    13  2018-12-30 10:00:00 PM      신항컨테이너부두03   HDMUULJT4854257
# 22046  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X36905
# 22047  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X38969
# 22048  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X39218
# 22049  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X39549
# 22050  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X40025
# 22051  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X41139
# 22052  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X41214
# 22053  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X41277
# 22054  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X41403
# 22055  S6EL2     9  2018-12-31 12:20:00 AM           정일컨부두        0058X41344
# 22058   D7NK    14  2018-12-31 05:30:00 AM           SK3부두        SWAN18048A
# 22059   D7NK    14  2018-12-31 05:30:00 AM           SK3부두        SWAN18048B
# 22060  3EEG9     8  2018-12-31 07:25:00 AM           유화1부두         ST188AUL2
# 22061  3ESK6    14  2018-12-31 09:05:00 AM           OTK부두           MRMA301
# 22067  D5CX8    10  2018-12-31 02:30:00 PM      신항컨테이너부두03   HDMUULIH4853259
# 22068  V7UP9    16  2018-12-31 02:30:00 PM      신항컨테이너부두01  NSSLUSNBC1800162
# 22069  V7UP9    16  2018-12-31 02:30:00 PM      신항컨테이너부두01  NSSLUSSHC1800749
# 22070  DSRP4    21  2018-12-31 03:00:00 PM        SK2부두 01    HVC18120201022
# 22075  DSQC6    30  2018-12-31 05:00:00 PM           정일2부두       SHOQSHC1834
# 22098  DSMB2    16  2018-12-31 08:00:00 PM           SK3부두       SC18123101A
# 22099  3EKI9     9  2018-12-31 08:18:00 PM            가스부두         CRUD1829A
# 22101  V2DW2     7  2018-12-31 09:00:00 PM      신항컨테이너부두02    KMTCUSN2111429
# 22102  V2DW2     7  2018-12-31 09:00:00 PM      신항컨테이너부두02    KMTCUSN2110419
# 22103  V2DW2     7  2018-12-31 09:00:00 PM      신항컨테이너부두02    KMTCUSN2119423
# 22105   D7BX    19  2018-12-31 10:30:00 PM        S-OIL1부두       SHSKEOS1806
#
#               업체명 수출입구분    적하항    양하항    품목코드  \
# 1       그레이트해운(주)    OO  KRUSN  TWTPE  271019
# 21      그레이트해운(주)    OO  KRUSN  TWTPE  290532
# 22      그레이트해운(주)    OO  KRUSN  TWTPE  271019
# 25      그레이트해운(주)    OO  KRUSN  TWTPE  271019
# 28        협운해운(주)    OO  KRUSN  CNZJG  293100
# 30      새한마리타임(주)    OO  KRUSN  CNRZH  293100
# 36        협운해운(주)    OO  KRUSN  CNZJG  293100
# 38        협운해운(주)    OO  KRUSN  CNJIA  293100
# 39        협운해운(주)    OO  KRUSN  CNZJG  293100
# 43        협운해운(주)    OO  KRUSN  CNJIA  293100
# 46        협운해운(주)    OO  KRUSN  CNZJG  293100
# 49        협운해운(주)    OO  KRUSN  CNZJG  293100
# 50        협운해운(주)    OO  KRUSN  CNZJG  293100
# 51        협운해운(주)    OO  KRUSN  CNZJG  293100
# 52        협운해운(주)    OO  KRUSN  CNZJG  293100
# 53        협운해운(주)    OO  KRUSN  CNJIA  293100
# 54      새한마리타임(주)    OO  KRUSN  CNYIZ  293100
# 55        우일해운(주)    OO  KRUSN  CNCAN  271000
# 57      그레이트해운(주)    OO  KRUSN  JPOSA  271300
# 58      그레이트해운(주)    OO  KRUSN  JPOSA  271300
# 63      (주)울산마리타임    OO  KRUSN  JPMIZ  271114
# 75        삼진선박(주)    OO  KRUSN  CNZOS  271000
# 78      그레이트해운(주)    OO  KRUSN  CNDLC  293100
# 79        한남해운(주)    OO  KRUSN  CNDGG  271000
# 80        한남해운(주)    OO  KRUSN  CNDGG  271000
# 81        아성마린(주)    OO  KRONS  CNZHE  271320
# 84     에스엠코리아주식회사    OO  KRUSN  VNSGN  271300
# 86      에스티오울산(주)    OO  KRUSN  CNTZO  293100
# 87      에스티오울산(주)    OO  KRUSN  CNZJG  293100
# 99      (주)울산마리타임    OO  KRUSN  CNLYG  271000
# ...           ...   ...    ...    ...     ...
# 22037     고려해운(주)    OO  KRUSN  SGSIN  291521
# 22038     고려해운(주)    OO  KRUSN  KRPUS  291736
# 22039     고려해운(주)    OO  KRUSN  SGSIN  291521
# 22040     현대상선(주)    OO  KRUSN  IDJKT  283325
# 22041     현대상선(주)    OO  KRUSN  IDJKT  283325
# 22046   그레이트해운(주)    OO  KRUSN  TWTPE  380899
# 22047   그레이트해운(주)    OO  KRUSN  MYPKG  291739
# 22048   그레이트해운(주)    OO  KRUSN  MYPKG  293371
# 22049   그레이트해운(주)    OO  KRUSN  TWTXG  291712
# 22050   그레이트해운(주)    OO  KRUSN  TWTXG  291712
# 22051   그레이트해운(주)    OO  KRUSN  TWTPE  281290
# 22052   그레이트해운(주)    OO  KRUSN  VNCLI  290949
# 22053   그레이트해운(주)    OO  KRUSN  VNCLI  271019
# 22054   그레이트해운(주)    OO  KRUSN  TWTXG  350610
# 22055   그레이트해운(주)    OO  KRUSN  TWTPE  284700
# 22058   그레이트해운(주)    OO  KRUSN  CNLYG  293100
# 22059   그레이트해운(주)    OO  KRUSN  CNLYG  293100
# 22060     가나해운(주)    OO  KRUSN  VNGDA  293100
# 22061       씨에스해운    II  JPMUR  KRUSN  271000
# 22067     현대상선(주)    OO  KRUSN  INMAA  340399
# 22068     남성해운(주)    OO  KRUSN  CNNGB  291739
# 22069     남성해운(주)    OO  KRUSN  CNSHA  291739
# 22070   (주)울산마리타임    OO  KRUSN  TWTXG  271320
# 22075   새한마리타임(주)    OO  KRUSN  CNSHP  293100
# 22098   (주)울산마리타임    OO  KRUSN  THKSI  293100
# 22099     신양상선(주)    OO  KRUSN  CNDYN  293100
# 22101     고려해운(주)    OO  KRUSN  JPNGO  292212
# 22102     고려해운(주)    OO  KRUSN  KRPUS  281111
# 22103     고려해운(주)    OO  KRUSN  JPNGO  292212
# 22105   그레이트해운(주)    OO  KRONS  JPISI  271300
#
#                                                       품명        중량톤  \
# 1      80 DRUMS  D-SOL 260R     12.88 MTS  * LUBRICAT...      14.40
# 21     PROPYLENE GLYCOL USP/EP 215KG STEEL DRUM CONTR...      18.64
# 22     80 DRUMS  D-SOL 260R   12.88 MTS  * LUBRICATIN...      14.40
# 25     120 DRUMS   YK-2831 14.94 MTS  YK-D130 4.98 MT...      22.08
# 28                            EOA DEA PMLADIETHANOLAMINE     400.01
# 30                                         SULFURIC ACID   8,900.00
# 36                       EOA TEA 99% PMLATRIETHANOLAMINE     789.22
# 38     PAPI TM 27 POLYMERIC MDIPOLYMETHYLENE POLYPHEN...   2,109.20
# 39                    MONOETHANOLAMINE (MEA)ETHANOLAMINE     515.08
# 43     VORANOL(TM) 8010G POLYOLGLYCEROL, PROPOXYLATED...   1,850.16
# 46     BUTYL CELLOSOLVE TM SOLVENTETHYLENE GLYCOL MON...     890.62
# 49     BUTYL CELLOSOLVE TM SOLVENTETHYLENE GLYCOL MON...     593.75
# 50     BUTYL CELLOSOLVE TM SOLVENTETHYLENE GLYCOL MON...     296.88
# 51                              EOA MEA PMLAETHANOLAMINE     515.08
# 52     BUTYL CELLOSOLVE TM SOLVENTETHYLENE GLYCOL MON...     197.92
# 53     BUTYL CARBITOLTM SOLVENTSPOLY(2-8)ALKYLENE GLY...     400.23
# 54                                             PROPYLENE   1,500.00
# 55                                              BASE OIL   1,900.00
# 57                      ASPHALT 80/100 PETROLEUM BITUMEN   1,400.00
# 58                      ASPHALT 80/100 PETROLEUM BITUMEN     500.00
# 63                                              ETHYLENE   3,558.99
# 75                                 LCO (LIGHT CYCLE OIL)  10,600.00
# 78                                            PARAXYLENE   5,000.00
# 79                                       TRIETHANOLAMINE     800.48
# 80                                        DIETHANOLAMINE     400.49
# 81                              ASPHALT 60-80 PENETRAION   5,067.15
# 84                           ASPHALT GRADE 60/70 IN BULK   4,064.22
# 86                                          ORTHO XYLENE   2,000.46
# 87                                          MIXED XYLENE   2,850.03
# 99                                MOLTEN SULPHUR IN BULK   2,999.36
# ...                                                  ...        ...
# 22037                                        ACETIC ACID      21.29
# 22038                   PURIFIED TEREPHTHALIC ACID (PTA)     750.04
# 22039                                        ACETIC ACID      63.87
# 22040                                       COPPER STRIP      12.10
# 22041                                       COPPER STRIP      11.21
# 22046  16PALLETS (640BAGS) OF POLYBUTYLENE TEREPHTHAL...      16.64
# 22047  COMMODITY : PURIFIED ISOPHTHALIC ACID(PIA) QUA...      20.06
# 22048  COMMODITY : CAPROLACTAM  QTY : 320MT  PACKING ...     326.40
# 22049  RHODIACID ADIPIC ACID  BIG BAG 1000 KG  CUSTOM...     161.68
# 22050  RHODIACID ADIPIC ACID BIG BAG  1000 KG D/THC P...      60.63
# 22051  NF3(NITROGEN TRIFLUORIDE) ,99.99% 1,600 KG BUN...       8.14
# 22052  DOWANOL(TM) PNP GLYCOL ETHER18DRUMS  180 KG ST...       1.18
# 22053  98.53MT OF BASE OIL 150N *VIETNAM TAX ID: 0309...      99.03
# 22054  NET WEIGHT 43,940 KGS OF LATEX DL935PA BULK L/...      43.94
# 22055  HYDROGEN PEROXIDE 60 PCT SPECIFICATIONS:AS DOC...     629.32
# 22058                                         PARAXYLENE   5,000.00
# 22059                                         PARAXYLENE   5,001.84
# 22060                                       MIXED XYLENE   2,000.00
# 22061                                             CUMENE   3,001.29
# 22067                           CUTTING OIL PREPARATIONS       2.82
# 22068                          PURIFIED ISOPHTHALIC ACID     702.21
# 22069                          PURIFIED ISOPHTHALIC ACID     501.58
# 22070                               PAVING ASPHALT 60/80   4,284.90
# 22075                                      SULFURIC ACID   8,800.00
# 22098                                BASE OIL (YUBASE 4)   3,540.00
# 22099                                          PROPYLENE   2,350.00
# 22101                                     DIETHANOLAMINE      18.24
# 22102                                         EMPTY TANK       0.00
# 22103                                     DIETHANOLAMINE      18.24
# 22105                                           KEROSENE   4,739.65
#
#              용적톤           하역업체명
# 1          20.00       만해항운한국(주)
# 21         24.62       만해항운한국(주)
# 22         20.00       만해항운한국(주)
# 25         30.00       만해항운한국(주)
# 28      4,999.99     (주)정일스톨트헤븐울
# 30     30,480.00     (주)정일스톨트헤븐울
# 36      4,999.99     (주)정일스톨트헤븐울
# 38      4,999.99     (주)정일스톨트헤븐울
# 39      2,200.00     (주)정일스톨트헤븐울
# 43      4,999.99     (주)정일스톨트헤븐울
# 46      4,999.99     (주)정일스톨트헤븐울
# 49      4,999.99     (주)정일스톨트헤븐울
# 50      4,999.99     (주)정일스톨트헤븐울
# 51      4,999.99     (주)정일스톨트헤븐울
# 52      4,999.99     (주)정일스톨트헤븐울
# 53      4,999.99     (주)정일스톨트헤븐울
# 54     17,289.79      SK에너지 주식회사
# 55     13,764.80    SK루브리컨츠 주식회사
# 57      8,500.75           협신컴퍼니
# 58      2,944.35           협신컴퍼니
# 63     39,684.14         대한유화(주)
# 75     83,492.20      SK에너지 주식회사
# 78     35,541.34   S-OIL (주)온산공장
# 79      4,534.95     (주)정일스톨트헤븐울
# 80      2,364.96     (주)정일스톨트헤븐울
# 81     30,659.22   S-OIL (주)온산공장
# 84     24,409.60      SK에너지 주식회사
# 86     14,239.57     주식회사태영인더스트리
# 87     20,600.00     (주)정일스톨트헤븐울
# 99     10,572.62      SK에너지 주식회사
# ...          ...             ...
# 22037      20.00         고려해운(주)
# 22038     870.40         고려해운(주)
# 22039      60.00         고려해운(주)
# 22040      12.10         현대상선(주)
# 22041      11.21         현대상선(주)
# 22046      29.74       만해항운한국(주)
# 22047      25.00       만해항운한국(주)
# 22048     500.00       만해항운한국(주)
# 22049     240.00       만해항운한국(주)
# 22050      90.00       만해항운한국(주)
# 22051      20.00       만해항운한국(주)
# 22052       1.85       만해항운한국(주)
# 22053     100.00       만해항운한국(주)
# 22054      43.94       만해항운한국(주)
# 22055     588.17       만해항운한국(주)
# 22058  35,996.53     SK종합화학 주식회사
# 22059  36,745.01     SK종합화학 주식회사
# 22060  15,128.34         대한유화(주)
# 22061  21,870.00  오드펠터미널코리아 주식회사
# 22067       4.58         현대상선(주)
# 22068     875.00         남성해운(주)
# 22069     625.00         남성해운(주)
# 22070  25,967.57      SK에너지 주식회사
# 22075  30,140.00     (주)정일스톨트헤븐울
# 22098  26,163.48    SK루브리컨츠 주식회사
# 22099  28,434.29   에스케이어드밴스드주식회사
# 22101      24.62         고려해운(주)
# 22102       0.00         고려해운(주)
# 22103      24.62         고려해운(주)
# 22105  37,780.05   S-OIL (주)온산공장
#
# [7841 rows x 14 columns]

# %%
from collections import Counter
aa18_count=Counter(aa18['품명'])
aa18_count
#입항횟수가 7이상인 품목코드만 뽑기
# Out:
# Counter({'80 DRUMS  D-SOL 260R     12.88 MTS  * LUBRICATINGBASE OIL': 1,
#          'PROPYLENE GLYCOL USP/EP 215KG STEEL DRUM CONTRACTNO.: DOW-17TW-P013 IN THE EVENT OF AN EMERGENCY PLE26-0560': 1,
#          '80 DRUMS  D-SOL 260R   12.88 MTS  * LUBRICATING BASE OIL': 1,
#          '120 DRUMS   YK-2831 14.94 MTS  YK-D130 4.98 MTS*LUBRICATING BASE OIL': 1,
#          'EOA DEA PMLADIETHANOLAMINE': 1,
#          'SULFURIC ACID': 55,
#          'EOA TEA 99% PMLATRIETHANOLAMINE': 1,
#          'PAPI TM 27 POLYMERIC MDIPOLYMETHYLENE POLYPHENYL ISOCYANATE': 6,
#          'MONOETHANOLAMINE (MEA)ETHANOLAMINE': 1,
#          'VORANOL(TM) 8010G POLYOLGLYCEROL, PROPOXYLATED ANDETHOXYLATED': 1,
#          'BUTYL CELLOSOLVE TM SOLVENTETHYLENE GLYCOL MONOALKYL ETHERS': 9,
#          'EOA MEA PMLAETHANOLAMINE': 1,
#          'BUTYL CARBITOLTM SOLVENTSPOLY(2-8)ALKYLENE GLYCOLMONOALKYL (C1-C6) ETHER': 1,
#          'PROPYLENE': 96,
#          'BASE OIL': 50,
#          'ASPHALT 80/100 PETROLEUM BITUMEN': 80,
#          'ETHYLENE': 5,
#          'LCO (LIGHT CYCLE OIL)': 5,
#          'PARAXYLENE': 145,
#          'TRIETHANOLAMINE': 6,
#          'DIETHANOLAMINE': 31,
#          'ASPHALT 60-80 PENETRAION': 1,
#          'ASPHALT GRADE 60/70 IN BULK': 1,
#          'ORTHO XYLENE': 4,
#          'MIXED XYLENE': 139,
#          'MOLTEN SULPHUR IN BULK': 58,
#          'ASPHALT RAS 100': 51,
#          'ASPHALT RAS 80': 53,
#          'AH-70 SK BRAND BULK ASPHALT.': 2,
#          'ASPHALT': 170,
#          'ASPHALT GRADE C170 IN BULK': 1,
#          'ASPHALT 60/80 PETROLEUM BITUMEN': 71,
#          'MOLTEN SULPHUR': 41,
#          'UNCONVERTED OIL  UCO': 1,
#          'BASE OIL (MDO-L)': 29,
#          '20MT HWF75SPHWF75SP PACKED IN 20 WOVEN SUPERSACKSWITH PLASTIC INNER,1MT NET EACH.HWF-1 PACKED IN 40BAGS,400KG NET EACH.': 1,
#          'LITHIUM HEXAFLUOROPHOSPHATE': 11,
#          'EMPTY TANK': 23,
#          'MIXTURE OF FLUORINE AND NITROGEN': 3,
#          'ADIPONITRILE': 58,
#          'UNCONVERTED OIL (UCO)': 48,
#          'PURIFIED ISOPHTHALIC ACID': 92,
#          'SODIUM HYDROSULPHITE': 9,
#          'C5(FRACTION)': 24,
#          'STYRENE MONOMER': 21,
#          'LUBRICATING BASE OIL': 446,
#          'DIMETHYL TEREPHTHALATE': 119,
#          'ETHANOL (ETHYL ALCOHOL)': 172,
#          'KEROSENE': 60,
#          'ADIPIC ACID': 90,
#          'ETHYLENE DIAMINE TETRA ACETIC ACID TETRASODIUMSALT': 18,
#          'ACETIC ACID': 236,
#          'PAINT': 47,
#          'C5 (FRACTION)': 5,
#          'TOLUENE': 157,
#          'PROPYLENE (REFINERY GRADE)': 10,
#          'NOCOLOK FLUX': 19,
#          'DIPIC ACID': 1,
#          'CUMENE': 39,
#          'C9AROMATICS': 46,
#          'ADDITIVE FOR LUBRICANTS': 18,
#          'METHYL CYCLOHEXANE': 8,
#          'BENZOYL PEROXIDE': 5,
#          'UCO': 2,
#          '80MT HWF50SP ALUMINUM': 1,
#          'RHODIACID ADIPIC ACID': 1,
#          'BASE OIL 150BS': 9,
#          'BASE OIL 500SN': 7,
#          'BENZENE': 112,
#          '3-ETHOXYPROPIONIC ACID ETHYL ESTER': 28,
#          'DIMETHYL TEREPHTHALTE': 1,
#          'STRAIGHT ASPHALT 60/80 PETROLEUM BITUMEN': 12,
#          'ACRYLONITRILE': 116,
#          'STRAIGHT ASPHALT 80/100 PETROLEUM BITUMEN': 10,
#          'PYGAS': 15,
#          'TERTIARY DODECYL MERCAPTAN': 18,
#          'N-HEPTANE 98PCT MIN': 1,
#          'SULPHUR HEXAFLUORIDE': 13,
#          'PHOSPHORODIFLUORIDIC ACID,LITHIUM SALT': 1,
#          'SUPER 31 LUBRICATING BASE OIL': 4,
#          'ULTRA-S 4(100N) LUBRICATING BASE OIL': 1,
#          'ULTRA-S 6 LUBRICATING BASE OIL': 2,
#          'ULTRA-S 2 LUBRICATING BASE OIL': 4,
#          'ULTRA-S 4 LUBRICATING BASE OIL': 4,
#          'YUBASE 4,YUBASE 6': 3,
#          'BASE OIL YUBASE 4,BASE OIL YUBASE 6': 7,
#          'MOLTEN SULFUR 99.8PCT MIN': 3,
#          'DIPROPYLENE GLYCOL': 67,
#          'HEXENE 1': 6,
#          'LUBRICATING BASE OIL ULTRA-S 2 ULTRA-S 4': 1,
#          'YUBASE 3 YUBASE 6 LUBRICATING BASE OIL': 8,
#          'YUBASE 4 LUBRICATING BASE OIL': 24,
#          'PROPYLENE IN BULK': 3,
#          'LUBRICATING OIL': 62,
#          'DIISOBUTYL KETONE': 9,
#          'BASE OIL ULTRA-S 2': 11,
#          'TETRACHLOROETHYLENEPERCHLOROETHYLENE PTAP': 4,
#          'POLYMER GRADE PROPYLENE': 108,
#          'BUNKER C': 6,
#          'CYCLOHEXANOL': 46,
#          '1-HEXENE': 5,
#          'LSFO': 12,
#          'SHELLSOL TK': 2,
#          'LUBE BASE OIL 500 SOLVENT NEUTRAL (2) 150 BRIGHT STOCK': 2,
#          '120MT HWF50SP 20MT HWF75SP ALUMINUM HYDROXIDEPACKED IN 140 WOVEN SUPERSACKSWITH PLASTIC INNER,1MT NET EACH.': 1,
#          '10PPM GAS OIL': 6,
#          'GASOLINE MOTOR SPIRIT': 16,
#          'TANK CONTAINER': 1,
#          'SODIUM HYDRO SULPHITE 85PCT MIN': 7,
#          'CATALYST': 1,
#          'USED PLATINUM CATALYST': 1,
#          'GAS OIL': 49,
#          'YUBASE 4 A LUBRICATING BASE OIL': 1,
#          'STAINLESS STEEL CANISTERS': 1,
#          'N-METHYLPYRROLIDONE DIST': 2,
#          'POTASSIUM IODIDE': 2,
#          'D-SOL 150L': 2,
#          'EPICHLOROHYDRIN (ECH)': 13,
#          'ALPHA OLEFIN C8': 21,
#          'ENGINE OIL': 13,
#          'REFINERY GRADE PROPYLENE': 17,
#          'METHYL ETHYL KETONE': 95,
#          'LUBRICANTING OIL': 1,
#          'LUBRICAING OIL': 1,
#          'TANK CONTAINERS': 1,
#          'BASE OIL ULTRA-S 2 (60N)': 1,
#          'MIXED-XYLENE': 23,
#          'D-SOL 200': 1,
#          'D-SOL 260R': 1,
#          'ALLYL ALCOHOL': 10,
#          'C8': 2,
#          'TOULENE': 1,
#          'SUPER 96 LUBRICATING BASE OIL': 2,
#          'ULTRA-S 3 LUBRICATING BASE OIL': 2,
#          'DIACIDS DBA FLAKES': 31,
#          'ANILINE': 5,
#          'SULFURIC ACID(H2SO4)': 18,
#          'POLYMERIC MDIPAPI 27 POLYMERIC MDI': 4,
#          'BASE OIL JOMO SOLVENT NEUTRAL 500EX': 2,
#          'ETHYL ALCOHOL': 70,
#          'POLYMER GRADE PROPYLENE IN BULK': 5,
#          'D E R 330 EPOXY RESINDIGLYCIDYL ETHER OF BISPHENOLA': 3,
#          'BASE OIL YUBASE 4BASE OIL YUBASE 6MARPOL ANNEX I OIL': 1,
#          'VINYL CHLORIDE MONOMER (VCM)': 1,
#          'ETHYLENE DICHLORIDE (E.D.C.)': 27,
#          'JET(JP-5)': 2,
#          'LUBRICATING  BASE OIL': 1,
#          'LIQUID PARAFFIN': 43,
#          'PROPYLENE (CHEMICAL GRADE)': 20,
#          'LIQUID PARAFIIN': 1,
#          'LUBRICATING BASE OIL ULTRA-S 4 (100N)': 3,
#          'LUBRICATING BASE OIL AROMAX T-DAE (E)': 8,
#          'LUBRICATING BASE OIL 60EX NEUTRAL': 8,
#          'PURIFIED TEREPHTHALIC ACID': 17,
#          'POTASSIUM HYDROXIDE': 23,
#          'YUBASE 6 LUBRICATING BASE OIL': 5,
#          'YUBASE 6J LUBRICATING BASE OIL': 5,
#          'POLYMERIC MDI': 10,
#          'META XYLENE': 21,
#          'PARA XYLENE': 70,
#          'SAFOL 23 ALCOHOLS (C12-C13)': 1,
#          'N-PROPANOL': 9,
#          'PROP BHNOXIOUS LIQUID': 2,
#          'SULFURIC ACID (H2SO4)': 1,
#          'PY-GAS': 4,
#          'CYCLOHEXANE': 46,
#          'METHYL ISOBUTYL KETONE': 7,
#          '10PPM GASOILGAS OIL': 1,
#          'GASOLINEMOTOR SPIRIT': 1,
#          'MOLTEN SULFUR 99.8PCT MIN.': 1,
#          'WHITE OIL': 1,
#          'YUBASE 4, YUBASE 6': 1,
#          'ACETIC ANHYDRIDE': 41,
#          'PROPYLENE GLYCOL INDUSTRIAL': 1,
#          'PROPYLENE GLYCOL': 138,
#          'CARBON BLACK FEED STOCK': 13,
#          'MIXED FATTY ACID   38.94MT OF MIXED FATTY ACID  PACKING IN FLEXIBAG   IN A 20  CONTAINER': 1,
#          'EHC 45 LUBE BASE OIL': 3,
#          'MONOETHANOLAMINE': 19,
#          'TRIETHANOLAMINE 99PCT': 3,
#          'MONOETHANOLAMINE(MEA)': 6,
#          'MDO-L LUBRICATING BASE OIL': 1,
#          'TANK CONTAINER EMPTY TANK  (AHF)': 1,
#          'SODIUM HYDROSULFITE 88': 1,
#          'ULTRA-S 2 (60N) LUBRICATING BASE OIL': 1,
#          'LIQUID ALKANES 150N': 10,
#          'DRY BULK LINER': 1,
#          'DOW CORNING (R) 2-0410 INT. ME 2 LINEARS-SPLITTER(DIMETHYL LINEARS)': 1,
#          'FLUXES': 5,
#          'GASOLINE': 24,
#          'ALPHAPLUS(R) 1-TETRADECENEOLEFINS (C13 ALL ISOMERS)': 6,
#          'ALPHAPLUS(R) 1-HEXADECENEOLEFINS (C13 ALL ISOMERS)': 2,
#          'TETRAMER 7POLYOLEFIN': 2,
#          'DER (TM) 383 LCL EPOXY RESINDIGLYCIDYL ETHER OF BISPHENOL A MARPOL': 8,
#          'ETHYLENE DICHLORIDE1,2-DICHLOROETHANE': 1,
#          'YUBASE 4 YUBASE 6 YUBASE 4 PLUS LUBRICATING BASE OIL': 7,
#          'THIOALCOHOLS': 44,
#          'TETRACHLOROETHYLENEPERCHLOROETHYLENE': 10,
#          'ETHYLENE DICHLORIDE': 6,
#          'ACETIC ACID GLACIAL': 44,
#          'VINYL ACETATE HQ 7-9': 1,
#          'LUBRICATING BASE OIL ULTRA-S 4': 1,
#          'THIOALCHOLSTERTIARY DODECYL MERCAPTAN': 1,
#          'HEXENE': 17,
#          'ACRYLO NITRILE': 2,
#          'BASE OIL YUBASE 3,BASE OIL YUBASE 4,BASE OIL YUBASE 6': 3,
#          'DIPROPYLENE GLYCOL(DPG)': 1,
#          'ACETIC ACID GLACIAL 99.85PCT MIN': 1,
#          'SULPHURIC ACID': 21,
#          'UNLEADED GASOLINE MOTOR SPIRIT': 7,
#          'TOLUENE (COAL TAR BASE)': 4,
#          'SODIUM BICARBONATE': 1,
#          'SODIUM HYDRO SULPHITE': 1,
#          'DOW CORNING (R) 2-0408(CYCLOPOLYDIMETHYLSILOXANE)': 4,
#          'ISOPHTHALIC ACID': 73,
#          'BENZENE TOLUENE XYLENE(CRUDE BENZENE)': 1,
#          'HYGOLD 5000BS MARPOL ANNEX I PETROLEUM OIL': 1,
#          'BASE OIL ULTRA-S 4': 3,
#          'EPICHLOROHYDRIN(ECH)': 1,
#          'EG': 2,
#          'TRIPROPYLENE GLYCOL': 17,
#          'TETRACHLOROETHYLENE': 3,
#          'AH-70 SK BRAND BULK ASPHALT': 40,
#          '2 ETHYL HEXYL ALCOHOL': 1,
#          'BITUMENASPHALT': 1,
#          'PYROLYSIS GASOLINE': 3,
#          'DOP(DI OCTYL PHTHALATE)': 7,
#          'DINP(DI ISO NONYL PHTHALATE)': 1,
#          'N-PROPANOL N-PROPYL ALCOHOL': 2,
#          'ETHANOL 99.9': 3,
#          'NAPHTHENIC BASE OIL U-46R 597,417MTNAPHTHENIC BASEOIL R-46 191,415MTNAPHTHENIC BASE OIL NR-9 163,756MT': 3,
#          'ETHYLENEGLYCOL MONO BUTYL ETHER': 3,
#          'AMMONIUM CHLORIDE  INDUSTRY GRADE': 1,
#          'EG(ETHYLENE GLYCOL)': 4,
#          'SK 500N LUBRICATING BASE OIL': 1,
#          'ACETONITRILE': 15,
#          'HEXANE': 2,
#          'SAFOL 23(C12-C13 ALCOHOLS)': 4,
#          'AP/E CORE 150 LUBE BASE OIL': 3,
#          'AMMONIUM BIFLUORIDE': 4,
#          'PROPYLENE GLYCOL USP(PGUSP)': 1,
#          'ETHYLENEDIAMINE (EDA)': 6,
#          'VORANOL (TM) 8010G POLYOLGLYCEROL PROPOXYLATED ANDETHOXYLATED': 4,
#          'BROMINATED POLYSTYRENE SD-70': 1,
#          'ENGINE OIL FOR AUTOMOTIVE': 27,
#          'TETRAMETHYL AMMONIUM HYDROXIDE': 3,
#          'NONENE(PROPYLENE TRIMER)': 3,
#          'LUBRICATING BASE OIL S-96 ULTRA-S 4ULTRA-S 8': 1,
#          'MONO ETHYLENE GLYCOL': 15,
#          'DI-ETHYLENE GLYCOL': 3,
#          'AH-90 SK BRAND BULK ASPHALT': 9,
#          'LITHIUM DIFLUORO(OXALATO)BORATE': 1,
#          'EMPTY CONTAINER': 1,
#          'EMPTY TANK(AHF)': 37,
#          'ADIPIC ACID   RHODIACID ADIPIC ACID BIG BAG 500KG': 1,
#          'EMPTY TANK (AHF)': 1,
#          'ISOPRENE MONOMER': 1,
#          'EPICHLOROHYDRIN': 14,
#          'ACETONE': 8,
#          'ASPHALT AH-70 IN BULK': 14,
#          'YUBASE L3 YUBASE 4A YUBASE 6 YUBASE 4 PLUSLUBRICATING BASE OIL': 1,
#          'SK AH-90 ASPHALT IN BULK': 20,
#          'PAPI 27 POLYMERIC MDI': 1,
#          'TERTIARY DODECYL MERCAPTAN (TDM)': 1,
#          'ANHYDROUS HYDROFLUORIC ACID': 2,
#          'LCO': 8,
#          'BASE OIL YUBASE 4, BASE OIL YUBASE 6': 2,
#          'ACETIC ANHYDRIDE IN BULK': 10,
#          'YUBASE 4 A YUBASE 6 YUBASE 4 PLUS LUBRICATING BASEOIL': 1,
#          'METHYLENE CHLORIDE': 4,
#          'INDUS OIL A1': 4,
#          'PARAFFIN 150N': 11,
#          'QUATERNARY AMMONIUM SALTS': 17,
#          'NORMAL BUTANOL': 7,
#          'ETHANOL': 4,
#          'ECH(EPICHLOROHYDRIN)': 1,
#          'EMPTY TANK CONTAINER': 2,
#          'C9 KOCOSOL-100': 1,
#          'NORMAL PARAFFIN C10-13': 3,
#          'YUBASE 2, YUBASE 3': 2,
#          'CYCLOHEXANONE': 8,
#          '1,2-DICHLOROETHANEETHYLENE DICHLORIDE': 1,
#          'ASPHALT AH-70': 19,
#          'NORMAL PARAFFIN C12-14': 6,
#          'ULTRA-S4 ULTRA-S6LUBRICATING BASE OIL': 1,
#          'ULTRA-S2LUBRICATING BASE OIL': 1,
#          'ULTRA-S2 ULTRA-S4 ULTRA-S6LUBRICATING BASE OIL': 1,
#          'JET (JP-5)': 6,
#          'ASPHALT PEN 60-80': 15,
#          'BUTYL CELLOSOLVE TM SOLVENT BULK': 7,
#          'BUTYL CELLOSOLV(TM) SOLVENT BULK': 1,
#          'BASE OIL YUBASE 3, BASE OIL YUBASE 4,BASE OIL YUBASE 4 PLUS, BASE OIL YUBASE 6': 1,
#          'VINYL ACETATE MONOMER': 16,
#          '10PPM GASOIL': 3,
#          'ALUMINIUM HYDROXIDE': 1,
#          'HIGH WHITE ALUMINIUM HYDROXIDE': 1,
#          'NAPHTHENIC BASE OIL R-46': 4,
#          'LUBRICATING BASE OIL YUBASE 3 YUBASE 6': 2,
#          'LUBRICATING BASE OIL SK 500N': 3,
#          'ETHYLIDENE NORBORNENE': 4,
#          'HYDROGEN FLUORID,ANHYDROUS': 1,
#          'DIETHANOLAMINE EOA DEA PMLA': 2,
#          'DIETHANOLAMINE EOA ETA PMLA': 1,
#          'LUBRICATING BASE OIL 500N(II)': 2,
#          'LUBRICATING BASE OIL 250VH 150N(II)': 1,
#          'LUBRICATING BASE OIL 250N(III)': 1,
#          'LUBRICATING BASE OIL 150N(II)': 1,
#          'LUBRICATING BASE OIL ARAMCO PRIMA 150(EXTENDER OIL150N(II))': 1,
#          'LUBRICATING BASE OIL ARAMCO PRIMA 500': 2,
#          'LUBRICATING BASE OIL ARAMCO PRIMA 500 ULTRA-S 8(250N)': 1,
#          'DOWANOL TM DPM GLYCOL ETHER(POLY (2-8) ALKYLENE GLYCOL MONOALKYL(C1-C6) ETHER': 1,
#          'DOWANOL TM PM GLYCOL ETHER(PROPYLENE GLYCOL MONOALKYL ETHER)': 9,
#          'PROPYLENE OXIDE': 26,
#          'BUTYL CELLOSOLVE TM SOLVENT': 21,
#          'BASE OIL 150N': 6,
#          'PARAFFIN OIL': 10,
#          'PARAFFIN OIL 150N': 4,
#          'MARINE DIESEL OILGAS OIL': 1,
#          'VINYL ACETATE MONOMER (VAM)': 1,
#          'ASPHALT AH-90': 7,
#          'DOWANOL (TM) PM GLYCOL STD GRADEPROPYLENE GLYCOL MONOALKYL ETHER': 1,
#          'ETHYLOL 95 DBNOXIOUS LIQUID': 1,
#          'YUBASE 2': 6,
#          'D-SOL 240 D-SOL 300KEROSENE PREPARATIONS': 1,
#          'SALT-BITTERN': 26,
#          'ALUMINUM HYDROXIDE': 18,
#          'DOW CORNING (R) 2-0410 INT. ME2 LINEARS-SPLITTER (DIMETHYL LINEARS)': 1,
#          'YUBASE 3 LUBRICATING BASE OIL': 4,
#          'LUBRICATING BASE OILYUBASE 4(R05939C)': 1,
#          'NIPAR S-10 IBBENGUREN NITROPROPANE': 1,
#          'NITROETHANE': 1,
#          'UNLEADED GASOLINEMOTOR SPIRIT': 2,
#          'KEROSENE PREPARATIONS': 31,
#          'SK 500N': 3,
#          'BASE OIL YUBASE 4': 2,
#          'BASE OIL YUBASE 6': 1,
#          'PLASTICIZER DINP': 3,
#          'SOLBITAL': 1,
#          'METHYL TERT BUTYL ETHER': 1,
#          'NITRIC ACID': 25,
#          'PHTHALIC ANHYDRIDE': 21,
#          'HSB 500N (DAESAN)': 7,
#          'METHYL METHACRYLATE MONOMER': 12,
#          'ACETONE, IN BULK': 2,
#          'ASPHALT GRADE AH-90': 2,
#          'NAPHTHENIC OIL - SNH 8HS': 1,
#          'ETHANOL(ETHYL ALCOHOL) IN BULKETHYL ALCOHOL': 1,
#          '20MT MAGNESIUM CHLORIDE YELLOW PRILL PACKED IN 25KG BAG': 1,
#          'PROPYLENE (POLYMER GRADE)': 14,
#          '2-ETHYL HEXANOL': 6,
#          'ASPHALT GRADE AH-70': 3,
#          'ETHANOL 99.9/UN': 4,
#          'SILICA POWDER': 3,
#          'YUBASE 4 PLUS, YUBASE 4A, YUBASE 6': 1,
#          'P-SOL 147': 1,
#          'ASPHALT C320': 1,
#          'LUBRICATING BASE OIL ULTRA-S 2 (60N)': 6,
#          'GASOIL': 22,
#          'SLO': 2,
#          'ANILINE AKL': 1,
#          'C4-RAFFINATE I': 1,
#          'ENSPRAY N 191.660 MT (SPRAY ADJUVANT)': 1,
#          'PURIFIRED ISOPHTHALIC ACID': 1,
#          'BASE OIL YUBASE 3,BASE OIL YUBASE 4A,BASE OIL YUBASE 6A': 1,
#          'DOW CORNING(R) 2-0408 (CYCLOPOLYDIMETHYLSILOXANE)': 1,
#          'SALT BITTERN': 6,
#          'COMPRESSED GAS, TOXIC, OXIDIZING, CORROSIVE,': 1,
#          'OMPRESSED GAS, TOXIC, OXIDIZING, CORROSIVE,': 1,
#          'HIGH WHITE ALUMINUM HYDROXIDE H-WF-10 100MT': 1,
#          'N-PROPANOL PROPYL ALCOHOL': 5,
#          'PRE-CUT WITH DB ETHYL ALCOHOL': 1,
#          'ASPHALT 60-80 PENETRATION': 4,
#          'TEREPHTHALIC ACID': 4,
#          'ANHYDROUS ETHANOL': 4,
#          'DI OCTYL TEREPHTHALATE': 1,
#          'METHYL ISO BUTYL KETONE': 3,
#          'N-PROPANOLN-PROPYL ALCOHOL': 4,
#          'SULFURIC ACID IN BULK': 10,
#          'ADDITIVE FOR LUBRICANTSLIQUID PARAFFIN': 1,
#          'ALPHAPLUS(R)1-DODECENE': 1,
#          'DOW CORNING (R)2-0408(CYCLOPOLYDIMETHYLSILOXANE)OCTAMETHYL CYCLOTETRASILOXANE': 1,
#          'LUBE BASE OIL (YUBASE 6 PLUS)': 2,
#          'LUBE BASE OIL (YUBASE 4 PLUS)': 2,
#          'YUBASE 4': 3,
#          'YUBASE 8J': 6,
#          '4 FLEXI BAGS OF  ALIPHATIC HYDROCARBON SOLVENT  ISU DE AROMATIC OIL 200   **IEC NO : 3494002177  GSTNO : 24AAACT7751N1ZY  EMAIL : INFOTASHOIL.COM': 1,
#          '11 TOTE-BINS & 9 CARTONS OF POLYACRYLAMIDE COUNTRYOF ORIGIN : KOREA OTHER ACRYLIC POLYMERS EMULSION,750 KG': 1,
#          'UCAR(TM) ESTER EEP BULK  UN 3272 CLASS 3  IN THE EVENT OF AN EMERGENCY  PLEASE CONTACT THE EMERGENCYSA0165,HWSTSA0167,  HWSTSA0168  GROSS WEIGHT:': 1,
#          'ENSPRAY N 191.050 MT (SPRAY ADJUVANT)': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3 IN THE EVENT OF AN EMERGENCY PLEASE CONTACT THE EMERGENCY RE201,HWSTSA0202, HWSTSA0203 GROSS WEIGHT: 23,680 KG': 1,
#          'NEODOL 25-7': 2,
#          'MGO GAS OIL': 1,
#          'JET A-1 JET FUEL': 1,
#          '1,4 BUTANEDIOL(BUTYLENE GLYCOL)': 2,
#          'PROPYLENE GLYCOL USP/EP': 6,
#          'POLY(2-8) ALKYLENE GLYCOL ETHER DE': 2,
#          'POLY(2-8) ALKYLENE GLYCOL ETHER DM': 3,
#          'MPDIOL GLYCOL(2-METHYL-1, 3-PROPANEDIOL)': 1,
#          'DOWANOL TM DPM GLYCOL ETHER(POLY (2-8) ALKYLENE GLYCOL MONOALKYL (C1-C6)ETHER)': 2,
#          'ULTRA-S 2 ULTRA-S 4 ULTRA-S 6 LUBRICATING BASE OIL': 2,
#          'ASPHALT 60/80 PEN': 1,
#          'THIOALCOHOLS TERTIARY DODECYL MERCAPTAN': 2,
#          'BASE OIL SK 120BS': 1,
#          'BASE OIL (SK 500N)': 3,
#          'BASE OIL YUBASE 6 (R05772A)': 1,
#          'BASE OIL (YUBASE 4)': 5,
#          'BASE OIL (YUBASE 6)': 2,
#          'BASE OIL (YUBASE 4 A)': 1,
#          'BASE OIL (YUBASE 3)': 3,
#          'BASE OIL YUBASE 4 (R05939C)': 1,
#          'KOCOSOL 150 SOLVENT': 1,
#          '320 PACKAGES OF LUBRICATING OIL MB GEO SAE 5W-40 MB 229.5 4X5LT:KR INV NO: M-VN 2100720971 / 8014538211 PO BTVN-201803-A02-MB': 1,
#          '320 PACKAGES OF LUBRICATING OIL MB GEO SAE 5W-40 MB 229.3 4X5LT:KR INV NO: M-VN 2100697593 / 8014538209 PO BTVN-201802-A13-MB': 1,
#          '320 PACKAGES OF LUBRICATING OIL MB GEO SAE 5W-40 MB 229.3 4X5LT:KR INV NO: M-VN 2100697595 / 8014538210 PO BTVN-201803-A14-MB': 1,
#          'TRICHLOROETHYLENE W': 2,
#          'BUTYL CELLOSOLV SOLVENT ETHYLENEGLYCOL MONO BUTYLETHER': 4,
#          'ECH;EPICHLOROHYDRIN;100%': 3,
#          'ADDITIVE FOR LUBRICANTSBASE OIL': 1,
#          'VORANOL POLYOL POLYXYPROPYLENE': 1,
#          'ETHYLENEDIAMINE': 1,
#          'LUBRICATING OILDAPHNE HERMETIC OIL FVC68D': 3,
#          'BASE OIL YUBASE 3BASE OIL YUBASE 4BASE OIL YUBASE6': 1,
#          'BASE OIL SK 500N': 2,
#          'SK AH-70 ASPHALT IN BULK': 7,
#          'CIMCLEAN 30 PINK': 1,
#          'POLYGLYCITOL SYRUP': 1,
#          'BASE OIL 2CST': 2,
#          'JET FUEL JETA-1': 1,
#          'HSB 500N (DAESAN': 2,
#          'SAFOL 23 ALCOHOL': 1,
#          'BASE OIL SK 120BS (WATER CONTAMINATION)': 1,
#          '15.5070MT OF PRIMO PLUS(UW) TW-20180410372-1': 1,
#          'RHODIACID ADIPIC ACID BIG BAG  1000KG D/THC PREPAID THE NUMBER OF THE CREDIT :F8AADN20044/2 DATED:20180531': 1,
#          '47.3MTS OF PROPYLENE GLYCOL USP GRADE 4.3MTS OF DIPROPYLENE GLYCOL FRAGRANCE GRADE PACKING: IN NET 2OREA': 1,
#          '320 PACKAGES OF LUBRICATING OIL MB GEO SAE 5W-40 MB 229.5 4X5LT:KR INV NO: M-VN 2100720975 / 8014540864 PO BTVN-201803-A03-MB': 1,
#          '320 PACKAGES OF LUBRICATING OIL MB GEO SAE 5W-40 MB 229.5 4X5LT:KR INV NO: M-VN 2100720976 / 8014540865 PO BTVN-201803-A04-MB': 1,
#          '20 PLTS (960 BAGS ON 20 PLTS) OF SORBITOL POWDER': 1,
#          'ENSPRAY N 191.150 MT (SPRAY ADJUVANT)': 1,
#          'HSFO 380': 2,
#          'BASE OIL ULTRA-S 6': 2,
#          'N,N-DIMETHYL FORMAMIDE': 2,
#          'VINYL ACETATE': 10,
#          'PROPYLENE(REFINERY GRADE)': 22,
#          'ULTRA-S 4 ULTRA-S 6 ARAMCO PRIMA 150 LUBRICATING BASE OIL': 1,
#          'PARA DICHLOROBENZENE': 1,
#          'LUBRICATING BASE OILAROMAX T-DAE (E)': 1,
#          'METHANOL': 11,
#          'NITRATING ACID(MIXTURE OF SULPHURIC AND NITRIC ACIDS)': 6,
#          'BASE OIL GS 600N': 1,
#          'RUBBER ANTIOXIDANT': 1,
#          'MIXED AROMATICS': 4,
#          'LUBE BASE OIL': 1,
#          'BOTTOM FATTY ACID   40M/TONS BOTTOM FATTY ACID  DISTILLATE (SOFT)': 1,
#          'PARAXYLENE IN BULKPARA XYLENE': 1,
#          'SILICA': 3,
#          'WHITE OIL YUBASE': 1,
#          'PROPYLENE GLYCOL USP': 8,
#          'SODIUM CYANIDE': 6,
#          '2-ETHYL HEXYL ALCOHOL': 12,
#          'SPECTRASYN 6POLYOLEFIN': 1,
#          'DIETHYLENE GLYCOL MONOBUTYL ETHER': 2,
#          'ENGINE OIL FOR MARINE USE': 9,
#          'POTASSIUM CARBONATE': 4,
#          'MIXED ACID OIL   59.95 MT OF MIXED ACID OIL  PACKING IN FLEXIBAG  FREIGHT PREPAID  NET WEIGHT : 59,950.00 KGS': 1,
#          'EXXAL 9S (ISO NONYL ALCOHOL)': 3,
#          'SOLVENT NAPHTHA M': 2,
#          'EXXSOL D80NOXIOUS LIQUID': 1,
#          'DIMETHYL AMINE (DMA) 50% 13.20 MT MANUFACTURER : LOTTE FINE CHEMICAL CO., LTD. *SHIPPED ON BOARD *DAS : 3 FREIGHT PREPAID': 1,
#          'ENSPRAY N 191.140 MT (SPRAY ADJUVANT)': 1,
#          'RHODIACID ADIPIC ACID BIG BAG 500KG D/THC PREPAID': 1,
#          'RHODIACID ADIPIC ACID 25 KG  RHODIACID ADIPIC ACIDBIG BAG 500KG  D/THC PREPAID  CUSTOMER ORDER NO.:20180502': 1,
#          '13.76MTS OF PROPYLENE GLYCOL USP GRADE 3.44MTS OFDIPROPYLENE GLYCOL FRAGRANCE GRADE PACKING: IN NET2KOREA CFR KEELUNG PORT, TAIWAN TAIWAN TEL: +886': 1,
#          'DOWANOL  DPNB GLYCOL ETHER 190KG STEEL DRUM DOWANOL* PNB GLYCOL ETHER 180KG STEEL DRUM IN THE EVENTOSE NUMBER 8-3999-0007  AGENT: WAN HAI (VIETNAM)': 1,
#          'UCAR(TM) ESTER EEP  BULK  UN 3272 CLASS 3   IN THEEVENT OF AN EMERGENCY  PLEASE CONTACT THE EMERGENC18991.018995.018998  AGENT DETAIL AT POD :  CHE': 1,
#          'BUTYL CARBITOL TM SOLVENTS': 1,
#          'YUBASE 4A': 2,
#          'D-SOL 200 KEROSENE PREPARATIONS': 2,
#          'D-SOL 240 KEROSENE PREPARATIONS': 2,
#          'CYPERMETHRINAGRICULTURAL INSECTICIDES': 1,
#          'PYRIBENZOXIM': 1,
#          'ETHANOL 99.9 UNETHYL ALCOHOL': 3,
#          'PALM FATTY ACID DISTILLATE': 13,
#          'ALPHA OLEFIN C14': 1,
#          'IP CLEAN LX': 2,
#          'DURASYN 164': 2,
#          'ACRYLONITRILE IN BULK': 1,
#          'MALEIC ANHYDRIDE (MOLTEN)': 3,
#          'PETROLEUM DISTILLATES': 14,
#          'DOW CORNING(R) 2-0410 INT. ME2 LINEARS SPLITTER(DIMETHYL LINEARS)': 1,
#          'BULK ASPHALT': 3,
#          'YK-D70(PETROLEUM OIL PREPARATION)': 1,
#          'YK-D130(PETROLEUM OIL PREPARATION)': 1,
#          'NEODENE 14': 3,
#          'NEODENE 16': 3,
#          'NEODENE 25-7': 1,
#          'FLOURINE/NITROGEN': 1,
#          'FLUORINE/NITROGEN(F2/N2) 25/75SULPHUR HEXAFLUORIDE(SF6)': 2,
#          '3-ETHOXYPROPIONIC ACID ETHYL ESTER UCAR ESTER EEP198 KG STEEL DRUM  UN 3272 CLASS 3': 1,
#          'ADPIC ACID': 1,
#          'AMMONIUM SULPHATE NITRATE': 2,
#          'AMMONIUM SULPHATE': 2,
#          'NICKEL SULFATE': 5,
#          'HEXAMETHYLENEDIAMINE': 6,
#          'YUBASE 6': 4,
#          'DIETHANOLAMINE(DEA)': 6,
#          'BUTYL CARBITOLTM SOLVENTSDIETHYLENE GLYCOL MONOBUTYL ETHER': 1,
#          'VORANOL 8010GPOLYOXYPROPYLENE': 1,
#          'VORANOLPOLYOXYPROPYLENE': 1,
#          'ACETON,ACETONITRILE,METHANOL,ETHYL ACETATE AH AND': 1,
#          'METHYL METHACRYLATE': 2,
#          '135 CARTONS & 5 TOTE-BINS OF POLYACRYLAMIDE COUNTRY OF ORIGIN : KOREA OTHER ACRYLIC POLYMERS GRANULEH 9,000 KG FO 4290 SSH 6,000 KG OKAFLOCK C-203 VHM': 1,
#          'BASE OIL ULTRA-S 2 (60N) 93.300MT TOTAL WEIGHT : 93.30MT PO: 4582015161 CNTR NO. / SEAL NO. GESU8052SK55702,SK55703 EXFU6609910/ SK55110,SK55120,SK551': 1,
#          'PRODUCT NAME QUANTITY  BASE OIL 150N 59.15 MT  (IN3 FLEXIBAGS)  BASE OIL 600N 39.46 MT  (IN 2 FLEXIB40 19.72MT 19.82MT 150N  OCGU2092190 19.71MT 19.8': 1,
#          'SILICON OIL XIAMETER(TM) PMX-0156 SILANOL FLUID 200 KG DR < LC NO. 8NBDBUL50009 LSD (LATEST SHIPMENTDATE): JUL.31, 2018 >': 1,
#          '**PH NO.:(02)2314-7311 FAX:(02)2388-5346 E-MAIL:EMILYHUNGTAIREN-ENT.CO M.TW TAX ID:04327859 SILICONOC:8PH2-03991W-100 LATEST SHIP DATE:180809 L.C': 1,
#          'HYDROSEAL G232HS (ALIPHATIC HYDROCARBON SOLVENT) HS CODE: 2710.19 SHIPPERS OWN ISO TANK CONTAINERS': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3  SEAL NO.034488,034489,034490': 1,
#          'VINYL ACETATE HQ': 1,
#          'HYDROGEN PEROXIDE': 3,
#          'TETRAHYDROFURAN': 9,
#          '2-METHYL-1,3-PROPANEDIOL': 3,
#          'SAFOL 23 ALCOHOL(C12-C13)': 1,
#          'MIX XYLENE': 4,
#          'C4-RAFFINATE 1': 5,
#          'VORANOL(TM) 8010G POLYOLPOLYOXYPROPYLENE': 1,
#          'EOA TEA PMLATRIETHANOLAMINE': 2,
#          'H.B.M. (VOLATILE OIL)': 7,
#          'PLASTICIZER DIOCTYL PHTHALATE': 1,
#          'PREMIUM 31 (STOCK 253)': 1,
#          'LUBRICATING BASE OIL YUBASE 6': 2,
#          'LUBRICATING BASE OIL YUBASE 6J': 2,
#          'LUBRICATING BASE OIL YUBASE 4': 2,
#          'COPPER STRIP': 17,
#          'NORMAL PARAFFIN': 7,
#          'LIGHT CYLE OIL': 1,
#          'AP/E CORE 600 LUBE BASE OIL': 5,
#          'ACETIC ACID IN BULK': 9,
#          'ASPHALT GRADE AH-70 IN BULK': 2,
#          'LUBRICATING OIL ENGINE OIL FOR MARINE USE': 1,
#          'HEXEN': 1,
#          'OCTENE': 2,
#          'PRODUCT NAME QUANTITY BASE OIL 60N / 98.30 MT (IN5FLEXIBAGS)': 1,
#          'BUTYL ACRYLATE (ALL ISOMERS)': 1,
#          'VINYL ACETATE HQ 7-9 PPM': 13,
#          'CHOLINE CHLORIDE': 3,
#          'FERROUS SULPHATE HEPTAHYDRATE': 2,
#          'ENSPRAY N 190.480 MT (SPRAY ADJUVANT)': 1,
#          'BASE OIL ULTRA-S 4 (100N) 19.050MT TOTAL WEIGHT :19.050MT PO: 4582015016 CNTR NO. / SEAL NO. WSDU6001067/ SK43164,SK43165,SK43166': 1,
#          'METHYLENE CHLORIDE UN NO. 1593 IMDG CLASS : 6.1 PACKING GROUP III': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3 IN THE EVENT OF AN EMERGENCY PLEASE CONTACT THE EMERGENCY REXFU0592553/20TK/ 700331/700355/700357 *TARE WEIGHT': 1,
#          '13.6MTS OF PENTAERYTHRITOL  99PERCENTAGE MIN  CREDIT NUMBER: MD1AK804NS00146  ** BUSAN 612-889, KOREA  TEL 82-51-744-9155 FAX 82-51-744-9160': 2,
#          '11X20GP CONTAINERS STC:- 176.000 GP-IBC (GOODPACKINTERMEDIATE BULK CONTAINER) TERMS OF PRICE:FOB PLAILAND AAR471A 4001220000 NATURAL RUBBER STR-20 T': 1,
#          'PVC PASTE RESIN': 14,
#          'MCH (METHYL CYCLOHEXANE)': 1,
#          '26X20 26TANKS HYDROGEN PEROXIDE 60 PCT SPECIFICATIONS:AS DOCUMENTS NO.EDK-1006-01 PACKING:IN ISO TANASS:5.1 UN NO:2015': 1,
#          'LUBRICATING OIL MOBIL 1 0W-40 CTN 12X1L (TIN) INVNO.: M-TW 2100786093 / 8014634723': 1,
#          'LUBRICATING BASE OIL 19.150 MT OF YUBASE 4 IN BULKNET WEIGHT : 19,150 KGS PURCHASE ORDER NO.: 441076K46808,SK46809': 1,
#          'BASE OIL ULTRA-S 2 (60N) 18.42MT TOTAL WEIGHT : 18.42MT PO: 4410761409 * CONTAINER NO. / SEAL NO. EXFU0602190/ SK55181,SK55182,SK55183': 1,
#          'LUBRICATING BASE OIL 19.190 MT OF YUBASE 4 IN BULKNET WEIGHT : 19,190 KGS PURCHASE ORDER NO.: 441076,SK55742,SK55743': 1,
#          'SYNTHETIC RUBBER KUMHO SBR1712   84.00MT THE METALBOXES SHOULD BE RETURNABLE GOODS.': 1,
#          'BASE OIL 150N - 19.74 MT IN FLEXIBAG BASE OIL 600N- 19.71 MT IN FLEXIBAG WHSU2191068 / WHLC403246 /1T / 19.81MT': 1,
#          'NITROGEN TRIFLUORIDE ISO CONTAINER FOR ABOVE GAS BUYER-OWNED ISO CONTAINER : 1TANK(20FT) IMDG CLASS:2.2 UN NO:2451': 4,
#          'COMMODITY  : CAPROLACTAM QTY :  560MT PACKING :25KGS IN BAG/PALLETIZED 16MT INTO 20FT CONTAINERAGENTAL BAGHDADIA AL GHARBIA DISTRICT, IBRAHIM SH': 1,
#          'ADIPIC ACID 500KGS POLY BULK BAG 20 MT 40 BAGS 1,000KGS POLY BULK BAG 100 MT 100 BAGS PO NO. / DATE:AK-ADA-3033 / 02-JUL-18': 1,
#          '1,4-BUTANEDIOL': 5,
#          'DMF(N,N-DIMETHYL FORMAMIDE)': 1,
#          'ENVIRONMENTALLY HAZARDOUS SUBSTANCE': 1,
#          'ORTHOXYLENE': 2,
#          '100.1MT HWF50SP ALUMINUM HYDROXIDE': 1,
#          'CHEMICAL PREPARATIONSTADIS 450': 2,
#          'JET A-1': 6,
#          'BUTYL ACRYLATE': 2,
#          'N-BUTANOL': 3,
#          'LIGHT CYCLE OIL (LCO)': 5,
#          'BASE OIL YUBASE 3,BASE OIL YUBASE 4,BASE OIL YUBASE 6,BASE OIL SK 500N': 1,
#          'LIGHT CYCLE OIL': 23,
#          'COPPER STRIP,SHEET': 2,
#          'BRASS STRIP JIS H3100': 1,
#          'BRASS STRIP': 8,
#          'NITRIC ACID 68PCT MIN': 2,
#          'DESCRIPTION PROPYLENE GLYCOL INDUSTRIAL': 1,
#          'N-BUTYL ACETATE': 28,
#          'YUBASE 4A, YUBASE 6, YUBASE 8, YUBASE 4 PLUS': 1,
#          'BUTYL CARBITOL TM SOLVENT': 3,
#          'BASE OIL SUN 500N': 2,
#          'LUBRICATING OILAPOLLOIL ATF RED-1': 2,
#          'LUBRICATING OILAPOLLOIL ATF D-3': 3,
#          'PETROLEUM OIL PREPARATIONS': 5,
#          'SAFOL 23 ALCOHOLS(C12-C13)': 1,
#          'DIPROPYLENE GLYCOL FRAGRANCE GRADE': 1,
#          'ASPHALT GRADE AH-90 IN BULK': 1,
#          'PVC COPOLYMER RESIN': 2,
#          'DIETHYLENE GLYCOL BUTYL ETHER': 1,
#          'GROUP I BASE OIL BS150': 1,
#          'FLUORINE/NITROGEN (F2/N2) 25/75SULPHUR HEXAFLUORIDE (SF6)': 1,
#          'ULTRA-S 4 ULTRA-S 6 LUBRICATING BASE OIL': 1,
#          'DER (TM) 331 EPOXY RESINDIGLYCIDYL ETHER OF BISPHENOL A MARPOL': 2,
#          'ALPHAPLUS(R) 1-HEXADECENEOLEFINS C13 ALL ISOMERS': 1,
#          'ALPHAPLUS(R) 1-DODECENE': 1,
#          'ETHYLENEDIAMINE(EDA)': 5,
#          'MIXED XYLENE (ISOMER GRADE)': 3,
#          'BUTYL CELLOSOLVE YM SOLVENT ETHYLENEGLYCOL MONO BUTYL ETHER': 3,
#          'BUTYL CARBRITOL SOLVENT DIETHYLENE GLYCOL MONO BUTYL ETHER': 2,
#          'POLYPROPYLENE RESIN': 2,
#          'DER(TM) 383 LCL EPOXY RESIN BULKDIGLYCIDYL ETHER OF BISPHENOL A MARPOL': 2,
#          '2-ETHYLHEXYL ACRYLATE': 4,
#          '80MT HWF50SP ALUMINUM HYDROXIDE': 1,
#          'DOWANOL PM GLYCOL ETHER': 3,
#          'BUTYL ACRYLATE (ALL ISOMERS) BA 15 PPM MEHQ': 1,
#          'STEARIC ACID': 5,
#          'LUBRICATING BASE OIL 38.330 MT OF YUBASE 4 IN BULKNET WEIGHT : 38,330 KGS 76.710 MT OF YUBASE 6 INBU8-0707 (POA-1805014) CONTAINER NO./SEAL NO. EURU': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3 IN THE EVENT OF AN EMERGENCY PLEASE CONTACT THE EMERGENCY REXFU0592682/20TK/700181/700191 /700194 *TARE WEIGHT': 1,
#          'COMMODITY : PURIFIED ISOPHTHALIC ACID(PIA) QUANTITY : 20 MT * IEC : 0812008723 GSTIN : 24AAKCA2207N1RVEELABS.COM': 17,
#          'RHODIACID ADIPIC ACID BIG BAG  1000 KG D/THC PREPAID': 4,
#          'CFR KEELUNG, TAIWAN 1).PROPYLENE GLYCOL USP GRADEQUANTITY:43MTS NET IN 215KG DRUMS 2).DIPROPYLENE GLDRUMS *CREDIT NUMBER:8NV2/00172/6153': 1,
#          'LUBRICATING OIL MOBIL 1 FS X2 5W-50 12X1L (TIN) MOBIL 1 5W-30 CTN 12X1L (TIN) INV NO.: M-TW 2100790419 / 8014678200': 1,
#          'LUBRICATING OIL MOBIL 1 FS X2 5W-50 12X1L (TIN) INV NO.: M-TW 2100790420 / 8014679093': 1,
#          'VORANOL(TM) 8010G POLYOLGLYCEROL PROPOXYLATED ANDETHOXYLATED': 1,
#          'PALM ACID OIL': 7,
#          'USED SUPPORTED CATALYSTS': 1,
#          'NITRIC ACID 68PCT': 1,
#          'DIPROPYLENE GLYCOL INDUSTRIAL GRADE': 1,
#          'COMMODITY:PURIFIED  ISOPHTHALIC ACID  QUANTITY: 1012MTS  PACKING: 1100KGS BAGS   GOODS ORIGIN: KOREA': 1,
#          'METHYL TERT-BUTYL ETHER': 1,
#          'ACID OIL': 1,
#          'DIETHANOLAMINE (DEA)': 3,
#          'AROMATIC POLYCARBOXYLIC ACIDS, THEIR ANHYDRIDES, HALIDES, PE': 1,
#          'H.B.M.(VOLATILE OIL)': 3,
#          'RHODIACID ADIPIC ACID BIG BAG  1000 KG THE NUMBEROF THE CREDIT: F8AADN20054/2 DATED 20180709 D/THCPREPAID': 1,
#          '80 DRUMS OF XIAMETER(R) PMX-0244 CYCLOTETRASILOXANE, 195 KG DRUM FLASH POINT : 57.00C UN 1993, IMDGCETRASILOXANE) 3, III <L/C:8NZ2002745301> PH NO.': 1,
#          'BASE OIL YUBASE 4,BASE OIL YUBASE 6,BASE OIL SK 500N': 1,
#          'LUBE BASE OIL 500 SOLVENT NEUTRAL(2) 150 BRIGHT STOCK': 1,
#          '2-ETHYL HEXYL AOCOHOL': 1,
#          'ASPHALT GRADE 60-80': 2,
#          'TERTIARY BUTYL ALCOHOL(TBA)': 1,
#          'AUTOMATIC TRANSMISSION FLUID': 1,
#          'ISONONYL ALCOHOL': 1,
#          'PROPYLENE OXIDE IN BULK': 1,
#          'ASPHALT 60/80': 6,
#          'JET FUEL': 10,
#          'ETHYL ACRYLATE': 1,
#          'DOP DI 2 ETHYL HEXYL ORTHOPHTHALATE': 3,
#          'BOTTOM DISTILLATE SOFT FA FLEXYBAG   BOTTOM FATTYACID DISTILLATE   PACKING IN FLEXIBAG  HS CODE: 3824.99.99': 1,
#          'BASE OIL 600N': 2,
#          'MIXED AROMATICS C9': 4,
#          'BOTTOM FATTY ACID DISTILLATE (SOFT) FFA (PALMITICACID) 40-60': 1,
#          'ANIONIC SURFACTANT': 1,
#          'BUTYL CARBITOLTM SOLVENTS': 3,
#          'TRICHLOROETHYLENE': 1,
#          'COMMODITY:PURIFIED  ISOPHTHALIC ACID  QUANTITY: 990MTS  PACKING: 1100KGS BAGS   GOODS ORIGIN: KOREA': 1,
#          'VINYL CHLORIDE MONOMER(VCM)': 3,
#          'DOW CORNING(R) 2-0408(CYCLOPOLYDIMETHYLSILOXANE)': 1,
#          'BRAZILIAN FERMENTATION HYDROUS ETHANOL NON DENATURATED FERMENTED FROM SUGARCANE AND OR SUGARCANE MOLASSES': 1,
#          'PROPYLENE (POLYMER GRADE) IN BULK': 2,
#          'INDUS OIL A5': 4,
#          'N, N-DIMETHYL FORMAMIDE': 2,
#          'LUBRICATING BASE OIL ULTRA-S 4(100N)': 1,
#          'ENSPRAY N 190.540 MT (SPRAY ADJUVANT)': 1,
#          'ENSPRAY N 114.370 MT (SPRAY ADJUVANT)': 1,
#          'CRUDE NICKEL SULFATE IMDG CLASS: 6.1 UN NO. 3288': 1,
#          '20MT OF ISOPHTHALIC ACID 99.8PCT CFR KAOHSIUNG EACH PACKAGE OF QUANTITY : 25KG NET WEIGHT : 25KG (1BASSK200038SU-Q IMPORT NO:07Q-361': 1,
#          'GROUP II 150N  BSIU2531678 20,130 KGS DFSU305021019,930 KGS HJLU1372254 20,150 KGS WHLU0692131 20,14ORE  *AGENT :  WAN HAI INTERNATIONAL PTE LTD 10 H': 1,
#          '64.5MTS OF PROPYLENE GLYCOL USP GRADE 4.3MTS OF DIPROPYLENE GLYCOL FRAGRANCE GRADE PACKING: IN NET 2OREA FAX: 886-2-2603-4686': 1,
#          'UNCONVERTED OIL': 5,
#          'H.P N-NEPTANE': 1,
#          'METHYL CYCLOHEXAN': 1,
#          '100MT HWF50SP ALUMINUM HYDROXIDE': 1,
#          'DILUTE NITRIC ACID': 1,
#          'CATALYST FOR STTEL': 1,
#          'LUBRICATING BASE OIL 19.10 MT OF YUBASE 4 IN BULKNET WEIGHT : 19,100 KGS PURCHASE ORDER NO.: 4410765SK55708,SK55709': 1,
#          'LUBRICATING BASE OIL 19.080 MT OF YUBASE 4 IN BULKNET WEIGHT : 19,080 KGS PURCHASE ORDER NO.: 441076,SK55468,SK55469': 1,
#          '80 DRUMS   D-SOL 260R 12.88 MTS  * LUBRICATING BASE OIL': 1,
#          '120 DRUMS   YK-2831 6.64 MTS  YK-D130 13.28 MTS* LUBRICATING BASE OIL': 2,
#          '120 DRUMS   YK-2831 13.28 MTS  YK-D130 6.64 MTS* LUBRICATING BASE OIL': 1,
#          '120 DRUMS   YK-2831 19.92 MTS   * LUBRICATING BASEOIL': 3,
#          'NF3(NITROGEN TRIFLUORIDE) ,99.99% 1,600 KG  BUNDLENO: 6,7,8,9,10  INVOICE NO: MB1807008A  UN NO: 2451 CLASS: 2.2': 1,
#          'NITROGEN TRIFLUORIDE 4,000KG (4N REFILLED IN ISO SKID, ISO SKID NO. HYCU1300069)  NITROGEN TRIFLUORIYCU1300074)  INVOICE NO:CGK073118, CGK073118-1  T': 1,
#          'SYNTHETIC RUBBER KUMHO SBR1502 10.50MT KUMHO KNB35L 6.30MT  TEL: 818-1031 / 818-1032 / 817-4560 /817-5265 (LOC.122)': 1,
#          'RHODIACID ADIPIC ACID  BIG BAG 1000 KG  D/THC PREPAID': 1,
#          'SILICON OIL XIAMETER(TM) PMX-0156 SILANOL FLUID 200 KG DR XIAMETER(TM) PMX-0156 SILANOL FLUID 200 KGDR < LC NO. 8NBDBUL50012 >': 1,
#          'ADIPIC ACID 500KGS POLY BULK BAG 80 MT 160 BAGS 1,000KGS POLY BULK BAG 0 MT 0 BAGS PO NO. / DATE : AK-ADA-3041 / 10-JUL-18': 1,
#          '2-METHYL-1.3-PROPANEDIOL': 1,
#          'SAFOL 23 (C12-C13 ALCOHOLS)': 3,
#          'PROPYLENE POLYMER GRADE': 1,
#          'REFINED FUEL OIL': 2,
#          'FLUORINE/NITROGEN(20%:80%)': 2,
#          'FLUORINE/NITROGEN(F2/N2) 25/75': 2,
#          'MIXED VEGETABLE OIL': 1,
#          'STEARIC ACID   STEARIC ACID 40 (WILFARIN SA-1840)-   HEAT STABLE': 1,
#          'CAUSTIC SODA LIQUID': 1,
#          'DIETHYLENEGLYCOL MONOBUTYL ETHER': 8,
#          'COPPER SHEET': 2,
#          '33.6MTS OF PENTAERYTHRITOL  99PERCENTAGE MIN  27.2MTS OF PENTAERYTHRITOL  99PERCENTAGE MIN   CREDITNNO: WHSU2013702,WHSU2360682 340 KGS BAGS IN CONT': 1,
#          '170MTS OF SODIUM FORMATE': 5,
#          '11X20GP CONTAINERS STC:- 176.000 GP-IBC  (GOODPACKINTERMEDIATE BULK CONTAINER)  TERMS OF PRICE : FON : THAILAND AAR471A 4001220000 NATURAL RUBBER ST': 1,
#          'YUBASE 4A, YUBASE 6': 3,
#          'YUBASE 6J': 2,
#          'PHENOL': 1,
#          'ETYLENE GLYCOL MONOALKYL ETHERSEASTMAN EB SOLVENT': 1,
#          '60.00 MT YUBASE 6  NET WEIGHT : 60,000 KGS  PURCHASE ORDER NO.:  LE-18-1207(POA-1806014)  CONTAINERNKASU4150414/  SK55821,SK55822,SK55823  KASU0240': 1,
#          '24X20 24TANKS HYDROGEN PEROXIDE 60 PCT SPECIFICATIONS:AS DOCUMENTS NO.EDK-1006-01 PACKING:IN ISO TANASS:5.1 UN NO:2015': 1,
#          'SYNTHETIC RUBBER KUMHO SBR1712  67.200MT THE METALBOXES SHOULD BE RETURNABLE GOODS.': 1,
#          'COMMODITY : DIPROPYLENE GLYCOL(DPG) 18,640KG *ORIGIN : REPUBLIC OF KOREA * PACKING : 215KGS NET IN N1 /82-2-772-8991 TEL/FAX : 886-4-24520777 /886-': 1,
#          'COMMODITY :  CAPROLACTAM FLAKES  QTY : 256000 KGSPACKING : 25KGS IN  BAG/PALLETIZED 16MT  INTO 20FT3AAACS0206P1ZL  EMAIL :  RAJESH.SHARMASRF.COM': 1,
#          'D.E.R (TM) 331 EPOXY RESINDIGLYCIDYL ETHER OF BISPHENOL A MARPOL': 1,
#          'DI(2-ETHYLHEXYL) TEREPHTHALATEAEKYUNG DOTP': 1,
#          'MARINE DIESEL OIL GAS OIL': 1,
#          'ISO NONANOL': 1,
#          'ISOPROPYL ALCOHOL': 4,
#          'A FUEL OIL': 1,
#          'SYNTHETIC ORGANIC DYES H.S. CODE NO. : DISPERSE DYES : 320411, ON 100 BASIS   DISPERSE BLUE 79 220- 4000.000 KG  CORALENE YELLOW BROWN 2RLS 150 -3000.000 KG  DISPERSE RED 311 P/C   1200.000 KG': 1,
#          'MIXED FATTY ACID': 3,
#          'REFINED GLYCERINE  99.7PERCENT   MIN-PALMATA 9970HS CODE : 2905.45': 1,
#          'MIXED ACID OIL SOLID HS CODE : 3823.19.10': 3,
#          'BOTTOM DISTILLATE SOFT FA MIXED ACID OIL   HS CODE: 3823199000': 1,
#          'VORANOL 8010G PMLA POLYOXYPROPYLENE': 1,
#          'ADIPICA ACID': 1,
#          'SAFOL 23': 4,
#          'PERCHLOROETHYLENE(PCE)': 3,
#          'HWF50SP ALUMINUM HYDROXIDE': 1,
#          'PERCHLOROETHYLENE FLUOROCARBON GRADE': 7,
#          'LIQUID PARAFFINN-ALKANES(C10)': 2,
#          'DISODIUM  DISODIUM': 2,
#          'MONOSODIUM L-GLUTAMATE  MONOSODIUM L-GLUTAMATE': 8,
#          'STEARIC ACID 40 72MT': 2,
#          'STEARIC ACID 40 24MT': 2,
#          'PARAXYLENE IN BULK': 2,
#          'BASE OIL YUBASE 3,BASE OIL YUBASE 4,BASE OIL YUBASE 6,BASE OIL SK 120BS': 1,
#          'ISO NONYL ALCOHOL': 5,
#          'USED PLATINUM CATALYST USED DEH-11 PACOL PLATINUMCATALYST': 2,
#          'DI PROPYLENE GLYCOL': 13,
#          'ISOL - HPETROLEUM OIL PREPERATIONS': 1,
#          'RESIN ACIDS, DERIVATIVES OF RESIN ACIDS AND ROSIN,ROSIN SPI': 4,
#          'PLASTICZER DIOCTYL PHTHALATE': 1,
#          'PREMIUM 31(STOCK 253)PREMIUM 96(STOCK 252)': 1,
#          'BASE OIL ULTRA-S 2BASE OIL ULTRA-S 4': 5,
#          'BASE OILARAMCO PRIMA 500': 1,
#          'BASE OILULTRA-S 4': 1,
#          'BASE OIL 150BS / 838.704MTBASE OIL 500SN / 750.281MT': 1,
#          'R B D PALM STEARIN': 1,
#          'PETROLEUM BITUMEN': 1,
#          'ULTRA-S 2(60N) LUBRICATING BASE OIL': 1,
#          'DIMETHYL TEREPHTHALATE (DMT)  BRIQUET TYPE': 4,
#          'BUTYL CELLOSOLVE (TM) SOLVENT BULK': 2,
#          'BUTYL CELLOSOLVE SOLVENT': 5,
#          'BASE OIL ULTRA-S 2 (60N) 186.480 MT TOTAL WEIGHT :186.48MT PO: 4582015380 CONTAINER NO./SEAL NO. KAS,144617,144639 KASU5110210/ 160770,160780,160790': 1,
#          'ENSPRAY N 190.610 MT (SPRAY ADJUVANT)': 1,
#          'COMMODITY:  PURIFIED ISOPHTHALIC ACID  QUANTITY: 1012MTS  PACKING: 1100KGS BAGS   GOODS ORIGIN: KOREA': 1,
#          '80 DRUMS OF UCAR* ESTER EEP 198 KG STEEL DRUM UN 3272 CLASS 3 *****WU-KU DIST. , NEW TAIPEI CITY, 24R.COM.TW FAX : 02-2292 4400 TEL : 02-2292 8811 IN': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3 IN THE EVENT OF AN EMERGENCY PLEASE CONTACT THE EMERGENCY RE192,HWSTSA0193, HWSTSA0194 GROSS WEIGHT: 24,210 KG': 1,
#          'MTBE': 1,
#          'REFRIGERANT GAS   R142B CLASS:2.1 UN NO:2517': 1,
#          'MIXED PALM FATTY ACID': 4,
#          'MIXED OIL FATTY ACID': 1,
#          'MIXED ACID OIL (SOLID)': 1,
#          'GAS OIL 3000 PPM': 1,
#          'YUBASE 4A, YUBASE 6A, YUBASE 6 PLUS': 1,
#          'BASE OIL HSB 150N': 1,
#          'SAFOL 23 (C12/13 ALCOHOL) BULK': 2,
#          'DOW CORNING(R)2-0408 (CYCLOPOLYDIMETHYLSILOXANE)DIMETHYL CYCLICS (DMC)': 1,
#          'YUBASE 4 YUBASE 6 YUBASE 4 PLUSLUBRICATING BASE OIL': 1,
#          'VORANOL(TM) 8010G POLYOL': 4,
#          'BUTYL CELLOSOLVE (TM) SOLVENT': 5,
#          'CFR KAOHSIUNG PORT PROPYLENE GLYCOL USP GRADE X 17.2MT AS PER PO3302-20180731001 CREDIT NUMBER: F8NOUL.31.2018': 1,
#          'NITROGEN TRIFLUORIDE 4,000KG (4N REFILLED IN ISO SKID, ISO SKID NO. HYCU1101112)  INVOICE NO: CGK081NO: 2451 CLASS: 2.2': 1,
#          'SILICON OIL XIAMETER(TM) PMX-0156 SILANOL FLUID 200 KG DR < LC NO. 8NBDBUL50014 >': 1,
#          'METHYLENE CHLORIDE UN NO. 1593 IMDG CLASS : 6.1 PACKING GROUP III ** CONTACT: PATT TEL :+662 689 6226': 1,
#          'NF3(NITROGEN TRIFLUORIDE),  99.99%,20 FEET TUBE TRAILER,  DISS SERIES,640,OXIDIZING/  TOXIC,PRODUCTG: 12,400 KG  NET WEIGHT: 4,000 KG   IMDG CLASS: 2': 1,
#          'RHODIACID ADIPIC ACID BIG BAG  1000 KG L/C NO. : F8ATAW2800096USB D/THC PREPAID': 1,
#          'NITRATING ACID(MIZTURE OF SULPHURIC ANG NITRIC ACIDS)': 1,
#          'STEARIC ACID 96 MT (160 BAGS)  STEARIC ACID 40 96MT': 1,
#          '50.4MTS OF PENTAERYTHRITOL  99PERCENTAGE MIN  13.6MTS OF PENTAERYTHRITOL  99PERCENTAGE MIN  CREDIT NL 82-51-744-9155 FAX 82-51-744-9160  420 KGS BAG': 1,
#          '4 ISO TANK CONTAINERS ISO BUTYL ACETATE QUANTITY :81.63MT PACKING : ISO-TANK CLASS 3 UN NO.1213': 1,
#          '10X20 CONTAINERS STC:- 160 GP-IBC AAR471A 4001220000 NATURAL RUBBER STR-20 QUANTITY: 201,600 KG ORIGATE BULK CONTAINER) CREDIT NUMBER: MD1431807ES001': 1,
#          'LUBRICATING BASE OIL  76.50 MT OF YUBASE 6 IN BULKNET WEIGHT : 76,500 KGS  PURCHASE ORDER NO.:  LE-1U0560962/  SK57531,SK57532,SK57533  SNCU3601250/': 1,
#          'MIXED FLUX': 1,
#          'YUBASE 2 YUBASE 3 YUBASE 6 PLUS LUBRICATING BASE OIL': 1,
#          '25X20 25TANKS HYDROGEN PEROXIDE 60 PCT SPECIFICATIONS:AS DOCUMENTS NO.EDK-1006-01 PACKING:IN ISO TANASS:5.1 UN NO:2015': 2,
#          'POTASSIUM HYDROXIDE FLAKES IMDG CLASS:8 UN NO: 1813': 1,
#          'BASE OIL 150N GROSS WEIGHT 19.84 MTS NET WEIGHT 19.74 MTS 1 FLEXI BAGS IN 1 20   CONTAINERS  BASE OI1 FLEXI BAGS IN 1 20   CONTAINERS  FREIGHT PREPAI': 1,
#          'RHODIACID ADIPIC ACID  BIG BAG 1000 KG  CUSTOMER PO 2412856439  MATERIAL 00544624  D/THC PREPAID': 1,
#          'P-8  (LUBRICATING BASE OIL)   *FACTORY :  1720-10,TAE JANG DONG,  WONJU-CITY, KANGWON-DO, KOREA  TEL: 82-2-443-0230,  FAX : 82-2-443-0235': 1,
#          'COPPER STRIP, SHEET': 1,
#          'POLYETHYLENE WAX': 1,
#          'ENSPRAY N 190.660 MT (SPRAY ADJUVANT)': 1,
#          'RHODIACID ADIPIC ACID 25 KG  RHODIACID ADIPIC ACIDBIG BAG 500 KG  CUSTOMER ORDER NO.  2018717  D/THCPREPAID': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3': 13,
#          '20PALLET(960BAGS) OF SORBITOL POWDER': 4,
#          'POLY VINYL CHLORIDE': 1,
#          'BASE OIL ULTRA S 4 (100N),BASE OIL ULTRA S 6 (150N),BASE OIL ULTRA S 8 (250N)': 1,
#          'HEPTANE': 2,
#          'LUBRICATING BASE OIL YUBASE 3 YUBASE 4 YUBASE 6 SK500N': 1,
#          'DOW CORNING(R) 2-0410 INT. ME2 LINEARS SPLITTER (DIMETHYL LINEARS)': 1,
#          'YUBASE 2, YUBASE 6, YUBASE 4A, YUBASE 4 PLUS': 2,
#          'CHLOROFORM': 7,
#          'CATALYST FOR STEEL MAKING REACTION': 2,
#          '2-ETHYLHEXYL ALCOHOL': 8,
#          'BASE OIL BS150': 1,
#          'METHYL TERT-BUTYL ETHERMTBE': 1,
#          'N-PROPANOL  PROPYL ALCOHOL': 1,
#          'OCTANOL': 1,
#          'COMMODITY : PURIFIED ISOPHTHALIC ACID(PIA) QUANTITY : 40 MT * IEC : 0812008723 GSTIN : 24AAKCA2207N1RVEELABS.COM': 3,
#          'RHODIACID ADIPIC ACID  BIG BAG 1000 KG  CUSTOMER PO2412856441  MATERIAL 00544624  D/THC PREPAID': 1,
#          '45.15MTS OF PROPYLENE GLYCOL USP GRADE 6.45MTS OFDIPROPYLENE GLYCOL FRAGRANCE GRADE PACKING: IN NET2KOREA': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3  SEAL NO.020125,020126,020127': 1,
#          'LUBRICATING OIL  MOBIL MULTIPURPOSE ATF  AUTOMATICTRANSMISSION FLUID  .  SHIPPERS OWN TANK CONTAINER.  TANK / SEAL NO  SWTU2241765/  181647,181697,': 1,
#          '80 DRUMS OF UCAR* ESTER EEP 198 KG STEEL DRUM UN 3272 CLASS 3 IN THE EVENT OF AN EMERGENCY PLEASE CONTACT THE EMERGENCY RESPONSE NUMBER 66-038-925400': 1,
#          'BASE OIL  39.34MT OF INDUSTRIAL  PARAFFIN 150N  39.48MT OF INDUSTRIAL  PARAFFIN 600N  * PACKAGE : 4F.67MT 19.77MT /150N  WHSU2326923  19.67MT 19.77': 1,
#          '19.67MT OF BASE OIL 600N  * PACKAGE : 1 FLEXI-BAGS**TEL: 84-28-5408 1162  FAX: 84-2862673070': 1,
#          '79.20MT OF MIXED FATTY ACID  PACKING IN 4 FLEXIBAGS': 1,
#          'MIXED FATTY ACID PACKED IN FLEXIBAG WITHOUT HEATING PAD  QUANTITY:101.510MT  H.S.CODE:3823.19.9000': 1,
#          'LUBRICATING OIL  MOBILGARD 5100  ENGINE OIL FOR MARINE USE': 1,
#          '59.99 MT OF BOTTOM FATTY ACID DISTILLATE  PACKINGIN FLEXIBAG  HS CODE: 3824.99.99': 1,
#          'BASE OIL SK 500N,BASE OIL SK 120BS': 1,
#          'MALEIC ANHYDRIDE': 14,
#          'PROPYLENE GLYCOL USP GRADE': 4,
#          'LUBRICATING OILGREASELE-18-1649/LE-18-1749': 1,
#          'DINP DI ISO NONYL PHTHALATE': 1,
#          'DOW CORNNING(R) 2-0410 INT ME2 LINEARS-SPLITTER(DIMETHYL LINEARS)': 1,
#          'ULTRA-S 2 LUBRICATING BASE OIL / 350MTARAMCO PRIMA150 / 200MT': 1,
#          'ULTRA-S 2 LUBRICATING BASE OILULTRA-S 4 ULTRA-S 6': 1,
#          'BRAZILIAN FERMENTATION HYDROUS ETHANOL': 1,
#          'LATEX IN FLEXIBAG': 2,
#          'COBALT SULFATE': 3,
#          'BASE OIL (PARAFFINIC BASE OIL YUBASE NO. 4)': 1,
#          'DESMODUR T80TOLUENE DIISOCYANATE': 1,
#          'ALPHA OLEFIN C8 (OCTENE-1)OCTENE (ALL ISOMERS)': 1,
#          'EOA MEA PMLA(MONOETHANOLAMINE)': 1,
#          'BASE OIL SN 500': 2,
#          'BASE OIL ULTRA S-8': 1,
#          'SN 800 LUBE BASE OIL': 2,
#          'EHC 50 LUBE BASE OIL': 1,
#          'EHC 110 LUBE BASE OIL': 1,
#          'ETHYLOL 95-DB ETHYLOL 95 DBNOXIOUS LIQUID': 1,
#          'PROPYLENE(POLYMER GRADE)': 1,
#          'C4 RAFFINATE-2': 1,
#          'NAPHTHENIC BASE OIL R-46 :794.380MTNAPHTHENIC BASEOIL U-46R :136.932MT': 2,
#          'STEARIC ACID 40 (WILFARIN SA-1840) - HEAT STABLEBUYER PO NO.4500055741  GROSS WEIGHT : 20.160 MTNET WEIGHT   : 20.000 MT': 1,
#          'STEARIC ACID 24MT    GROSS WEIGHT : 24.192 MT  NETWEIGHT   : 24.000 MT': 1,
#          'ETHYLENE GLYCOL MONOALKYL ETHERS EB SOLVENT': 1,
#          'ETHYLENE GLYCOL BUTYL ETHER EB ACETATE': 1,
#          'MPDIOL GLYCOL': 1,
#          'ADIPIC ACIDS': 1,
#          'APE CORE 600 LUBE BASE OIL': 1,
#          'APE CORE 2500 LUBE BASE OIL': 1,
#          '84.0MTS OF PENTAERYTHRITOL  99PERCENTAGE MIN  CREDIT NUMBER: MD1AK1807NS00356  ** BUSAN 612-889, KOREA  TEL 82-51-744-9155 FAX 82-51-744-9160': 1,
#          'NITROGEN TRIFLUORIDE  4,000 KG (4N REFILLED IN ISOSKID, ISO SKID NO. HYCU1600220) INVOICE NO: CGK083118-2 UNNO: 2451 CLASS: 2.2': 1,
#          'MIXED FLUX AND LUBRICANT': 1,
#          '15X20 15TANKS HYDROGEN PEROXIDE 60 PCT SPECIFICATIONS:AS DOCUMENTS NO.EDK-1006-01 PACKING:IN ISO TANASS:5.1 UN NO:2015': 1,
#          '19.69MT OF BASE OIL 150N   **TEL: 84-8-37551028,FAX: 84-8-37552009   *CONTAINER NO/N.W/G.W:  DFSU3033721 19.69MT 19.79MT': 1,
#          'CAPROLACTAM QTY 176.0 MT  AS PER BENEFICIARYS  PROFORMA INVOICE NO.  1808-9502B  DATED 13 AUG 2018LEAUG.23,2018   LC NO. AND DATE :  28418IMPLC0': 1,
#          'ADIPIC ACID 500KGS POLY BULK BAG 20 MT 40 BAGS 1,000KGS POLY BULK BAG 140 MT 140 BAGS PO NO. / DATE:AK-ADA-3075 / 24-AUG-18': 1,
#          'ADIPIC ACID 500KGS POLY BULK BAG 20 MT 40 BAGS 1,000KGS POLY BULK BAG 0 MT 0 BAGS PO NO. / DATE : AK-ADA-3076 / 24-AUG-18': 1,
#          'NOCOLOK DRY STATIC': 1,
#          'KIXX LUBE 150N(LIQUID PARAFFIN) LUBRICATING BASE OIL': 1,
#          'KIXX LUBE 600N(LIQUID PARAFFIN) LUBRICATING BASE OIL': 1,
#          'ENSPRAY N 189.940  MT (SPRAY ADJUVANT)': 1,
#          'SAFOL 23(C12/13 ALCOHOL) DANGEROUS GOODS(3082,9) SHIPPERS OWN TANK CONTAINER STOLT REF NO-10190392CNGROSS WET:22,800KG NET WET:19,000KG TARE WET:380': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3  *SEAL NO.039344/039785/039837': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3  SEAL NO.036936/036937/036939': 1,
#          'POLY(ETHYLENE TEREPHTHALATE)': 2,
#          'LUBRICATING BASE OIL YUBASE 3 YUBASE 4 YUBASE 6 SK500N SK 120BS': 1,
#          'LUBRICATING BASE OIL YUBASE 4 YUBASE 6': 1,
#          'MIXED PALM FATTY ACID 312.670 MT': 1,
#          'BOTTOM DISTILLATE SOFT FA BOTTOM FATTY ACID DISTILLATE   IN FLEXIBAG': 1,
#          'MIXED FATTY ACID 197.300MT': 1,
#          'SAFOL 23  ALCOHOLS': 1,
#          'MONOETHANOLAMINE (MEA)': 1,
#          'ASPHALT GRADE 80-100': 1,
#          'ASPHALT GRADE 100-110': 1,
#          'ETHANOL 99.9UNETHYL ALCOHOL': 1,
#          'DICYCLOPENTADIENE RESIN GRADE': 1,
#          'ISO PROPYL ALCOHOL': 5,
#          'SULFUR': 7,
#          'SULPHUR': 6,
#          'LUBRICATING OIL LE-18-1611HS CODE:3403.99': 1,
#          'SULPHURIC ACID IN BULK': 2,
#          'STEARIC ACID 76MT': 1,
#          'BUNDLE OF CYLINDER(1BUNDLE=12CYL/50L)FLUORINE/NITROGEN(20%:80%)': 1,
#          'KOFERISPOLY FERRIC SULFATE': 1,
#          'SULPHATES (EXCL. OF SODIUM, MAGNESIUM, ALUMINIUM,NICKEL, CO': 1,
#          'MIXED XYLENE IN BULK': 1,
#          'HEXADECENE': 1,
#          '1-TETRADECEN': 1,
#          'SLURRY OIL': 1,
#          'CYCLOPENTANE': 3,
#          'LIQUID PARAFFFIN': 1,
#          'XYLENE': 1,
#          'LINEAR ALKYL BENZENE': 2,
#          'LUBRICATING BASE OIL ARAMCO PRIMA 150(EXTENDER OIL150N(II)': 1,
#          'SK 330 OILS OTHER PRODUCTS': 1,
#          'POLYACETAL RESIN KEPITAL': 5,
#          'HS CODE: 291712 RHODIACID ADIPIC ACID BIG BAG 500KG PO NO.4509699693': 1,
#          'BASE OIL ULTRA-S 2 (60N) 94.270MT TOTAL WEIGHT : 94.270MT PO: 4582015552 * CNTR NO. / SEAL NO. WSDU654,SK61255,SK61256 SNCU8002173/ SK61974,SK61975,SK': 1,
#          'COMMODITY: PURIFIED ISOPHTHALIC ACID QUANTITY:1518MTS PACKING:1100KGS BAGS': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3  SEAL NO.041885/041891/041894': 1,
#          'PIA(ISOPHTHALIC ACID)  QTY:40 TONS  CONTRACT NO.20553903  THIS L/C NO:F8ATAD2800123USO': 1,
#          'NEODENE 14 OLEFINS (C13 ALL ISOMERS)': 4,
#          'DER (TM) 383 LCL EPOXY RESIN DIGLYCIDYL ETHEROF BISPHENOL A MARPOL': 2,
#          'ALPHAPLUS (R) 1-DODECENE': 1,
#          'ALPHAPLUS (R) C-14 TETRADECENE OLEFINS(C13 ALL ISOMERS)': 1,
#          'ALPHAPLUS (R) 1-HEXADECENE OLEFINS C13 ALL ISOMERS': 1,
#          'TETRAMER 7 POLYOLEFIN': 1,
#          'NEODENE 16 OLEFINS (C13 ALL ISOMERS)': 3,
#          'DIETHYLENEGLYCOL MONOBUTYL ETHER   BUTYL CARBITOLSOLVENT 193KG  STEEL DRUM': 1,
#          'YUBASE 2 LUBRICATING BASE OIL': 1,
#          'YUBASE 4A LUBRICATING BASE OIL': 1,
#          'RUBBER PROCESSING OIL 150N': 1,
#          'CUTTING OIL PREPARATIONS': 3,
#          '1,4 BUTANEDIOL': 2,
#          '13.6MTS OF PENTAERYTHRITOL 99PERCENTAGE MIN  CREDIT NUMBER: MD1AK1807NS00356  ** BUSAN 612-889, KOREA TEL 82-51-744-9155 FAX 82-51-744-9160': 1,
#          'LUBRICATING OIL MOBIL 1 5W-30 CTN 12X1L (TIN) INVNO.: M-TW 2100882224 / 8014877674': 1,
#          'LUBRICATING OIL MOBIL 1 FS X2 5W-50 12X1L (TIN) INV NO.: M-TW 2100882264 / 8014877671': 1,
#          'ADIPIC ACID 500KGS POLY BULK BAG 60 MT 120 BAGS 1,000KGS POLY BULK BAG 0 MT 0 BAGS PO NO. / DATE : AK-ADA-3069 / 16-AUG-18': 1,
#          '240MT(12 FCLS) SODIUM CYANIDE BRIQUETTE CFR SURABAYA,INDONESIA SODIUM CYANIDE 98% MIN(NACN) PACKAGINMDG CLASS:6.1 UN NO:1689': 1,
#          'CFR KEELUNG, TAIWAN 1)PROPYLENE GLYCOL USP GRADE QUANTITY: 34.40MTS NET IN 215KG DRUMS *CREDIT NUMBER: 8NV2/00193/9153': 1,
#          'CFR KEELUNG, TAIWAN  2).DIPROPYLENE GLYCOL  FRAGRANCE GRADE  QUANTITY:17.2MTS NET IN  215KG DRUMS  *CREDIT NUMBER:  8NV2/00193/9153': 1,
#          '20MT OF ISOPHTHALIC ACID  99.8PCT  CFR KAOHSIUNGEACH PACKAGE OF  QUANTITY: 25KG  NET WEIGHT:25KG(1BAK200046SU-Q  IMPORT NO:07Q-393': 1,
#          'BASE OIL 150N **FAX +82 31 708 3476 ++LONG AN PROVINCE, VIETNAM': 1,
#          'SAFOL 23(C12/13 ALCOHOL) DANGEROUS GOODS(3082,9) SHIPPERS OWN TANK CONTAINER STOLT REF NO-10195150CNGROSS WET:22,800KG NET WET:19,000KG TARE WET:380': 1,
#          '80 DRUMS OF UCAR ESTER EEP 198 KG STEEL DRUM UN 3272 IMDG CLASS 3 IN THE EVENT OF AN EMERGENCY PLEAS400': 1,
#          '39.34MT OF BASE OIL 600N   *CONTAINER NO/N.W./G.W.:  WHSU2332926 19.66MT 19.76MT  WHLU2872699 19.68MT 19.78MT': 1,
#          'BASE OIL 150N   **TEL: +84(251)3.647 600,  FAX: +84(251)3.647 680   *CONTAINER NO/N.W/G.W :  HJLU1364109 19.78MT 19.88MT': 1,
#          'LUBRICATING OIL  MOBIL RARUS 427 P20LT  MOBIL VELOCITE NO 3 PAIL 20L  MOBIL VELOCITE 6, 20LT, PAILM-P 5W30 12X1L:KR (TIN)  INV NO.: M-TW  210086541': 1,
#          'RHODIACID ADIPIC ACID BIG BAG  1000KG L/C NO. : F8ATAW2800108USB D/THC PREPAID': 1,
#          'PROPYLENE GLYCOL (PG)': 1,
#          'MIXED ACID OIL LIQUID QUANTITY : 100MT  PACKING :IN FLEXIBAG  5 FLEXIBAGS IN TOTAL': 1,
#          'MIXED ACID OIL SOLID  SOLID-FLB-BULK  DETAILS AS PER OFFER NO. PI-18-SC3098': 1,
#          '20 PALLETS(TWENTY PALLETS ONLY)  20 PALLETS CONTAINING 240 CARTONS & 20 FIBC  SYNTHETIC ORGANIC DYES,  H.S.CODE NO.: DISPERSE DYES: 320411 ETC': 1,
#          'MIXED ACID OIL SOLID': 3,
#          '59.96 MT OF MIXED ACID OIL PACKING IN FLEXIBAG  COUNTRY OF ORIGIN: INDONESIA CIF ULSAN  HS CODE: 3823199000': 1,
#          'DILUTE NITRIC ACID (NITRIC ACID 68%)': 1,
#          'MIXED XYLEN': 1,
#          'METHA XYLENE': 1,
#          'SHELL 150N(DAESAN) LUBRICATING BASE OIL': 1,
#          'SHELL 500N(DAESAN) LUBRICATING BASE OIL': 1,
#          '67.2MTS OF PENTAERYTHRITOL 99PERCENTAGE MIN  CREDIT NUMBER: MD1AK1807NS00491  ** BUSAN 612-889, KOREA TEL 82-51-744-9155 FAX 82-51-744-9160': 1,
#          'N, N-DIMETHYL FORMAMIDE 99.9PCT MIN': 1,
#          'LUBRICATING BASE OIL 19.120MT OF YUBASE 4 IN BULKNET WEIGHT : 19,120 KGS PURCHASE ORDER NO.: 44107717,SK62128,SK62129 * NON-DANGEROUS GOODS * SHIPPE': 1,
#          'COMMODITY  : CAPROLACTAM QTY :  512MT PACKING : 25KGS IN BAG/PALLETIZED 16MT INTO 20FT CONTAINER  1.CC2491D1ZY 3.  EMIAL(EMAIL)   : D': 1,
#          'RHODIACID ADIPIC ACID BIG BAG  500KG D/THC PREPAIDCREDIT NUMBER: F8ATAW2800107USB': 1,
#          'BASE OIL 600N GROSS WEIGHT 19.58 MTS NET WEIGHT 19.48 MTS 1 FLEXI BAG IN 1 20   CONTAINER': 1,
#          '20.06 MT OF TRIPROPYLENE GLYCOL  ( CIF KAOHSIUNG )PACKING : IN ISO TANK  ORIGIN : REP. OF KOREA  NOT NO. : 07J-202  EOLU8246929/009718/009779/0097': 1,
#          '98.64MT OF LIQUID ALKANES 150N  BASE OIL 2CST   *CONTAINER NO/N.W./G.W. :  WHLU0466094 19.75 MT 19.89.74 MT 19.84 MT  WHLU0465647 19.69 MT 19.79 MT  W': 1,
#          'RHODIACID ADIPIC ACID BIG BAG 500KG': 1,
#          'LUBRICATING OIL MOBIL 1 0W-40 CTN 12X1L (TIN) INVNO.: M-TW 2100882261 / 8014917732': 1,
#          'NITROGEN TRIFLUORIDE ISO CONTAINER FOR ABOVE GAS BUYER-OWNED ISO CONTAINER : 1TANK(20FT)  NITROGEN TED ISO CONTAINER : 1TANK(20FT)  IMDG CLASS:2.2 UN': 1,
#          'NITROGEN TRIFLUORIDE 4,000KG (4N REFILLED IN ISO SKID, ISO SKID NO. HYCU1600235)  INVOICE NO: CGK091UNNO: 2451 CLASS: 2.2': 1,
#          'LUBRICATING OIL MOBIL 1 0W-40 CTN 12X1L (TIN) MOBIL 1 ESP 5W30 12X1L (TIN) INV NO.: M-TW 2100882262/8014924616': 1,
#          'TRANSFORMER OIL': 9,
#          'BARIUM SULPHATE': 1,
#          'SODIUM ALUMINATE': 4,
#          'VORANOL (TM) 8010G POLYOL POLYOXYPROPYLENE': 1,
#          'PURIFIED ISOPHTHALIC ACID(PIA)': 3,
#          '10X20 CONTAINERS STC:- 160 GP-IBC AAR471A 4001220000 NATURAL RUBBER STR-20 QUANTITY: 201,600 KGORIGITE BULK CONTAINER) CREDIT NUMBER:  MD1431': 1,
#          'COMMODITY : MIXED ACID OIL (SOLID) QUANTITY: 100 MT COUNTRY OF ORIGIN: INDONESIA TERM OF PRICE :  FOAGS IN TOTAL LOADED IN 5 CONTAINERS/20FT L/C NO.': 1,
#          'BURYL ACRYLATE BA 15 PPM MEHQ': 1,
#          'PROPYLENE(POLYMER GRADE) IN BULK': 1,
#          'TETRAHYDROPHTHALIC ANHYDRIDE TETRAHYDROPHTHALIC ANHYDRIDE': 2,
#          'LUBRICATING BASE OIL 76.410 MT OF YUBASE 6 IN BULKNET WEIGHT : 76,410 KGS PURCHASE ORDER NO.: LE-18-870/ SK62124,SK62125,SK62126 TCLU9011160/ SK61927': 1,
#          '23X20 23TANKS HYDROGEN PEROXIDE 60 PCT SPECIFICATIONS:AS DOCUMENTS NO.EDK-1006-01 PACKING:IN ISO TANASS:5.1 UN NO:2015': 1,
#          '80 DRUMS   D-SOL 260R 12.88 MTS   * LUBRICATING BASE OIL': 1,
#          '120 DRUMS   YK-D130 19.92 MTS   * LUBRICATING BASEOIL': 1,
#          '37.00 MT OF METHYLENE CHLORIDE  KOREA ORIGIN': 1,
#          'HS CODE: 290532 PROPYLENE GLYCOL-USP GRADE (PG USP) 21.49MT': 1,
#          'CFR TAICHUNG PORT  2).PROPYLENE GLYCOL USP GRADEQUANTITY:17.2MTS NET IN  215KG DRUMS  TO TAICHUNGPORT  *CREDIT NUMBER:8NV2/00208/1153': 1,
#          'RHODIACID ADIPIC ACID BIG BAG  1000 KG D/THC PREPAID CUSTOMER PO 2412891828 MATERIAL 00544624': 1,
#          'BASE OIL 150N - NW: 19.75 MT BASE OIL 600N - NW: 38.94 MT': 1,
#          'ADIPIC ACID 500KGS POLY BULK BAG 20 MT 40 BAGS 1,000KGS POLY BULK BAG 0 MT 0 BAGS PO NO. / DATE : AK-ADA-3085 / 10-SEP-18': 1,
#          'ASPHALT 80/100': 6,
#          'PRESSURIZED POLYMER GRADE PROPYLENE': 1,
#          '59.96 MT OF BOTTOM FATTY ACID DISTILLATE': 1,
#          'ETHYLOL 95DBNOXIOUS LIQUID': 1,
#          'MIXED PALM FATTY OIL(HS CODE:3823.19.9000)  PACKEDIN FLEXIBAGS,WITHOUT HEATING PAD  COUNTRY OF ORIGIN : MALAYSIA': 1,
#          'REFRIGERANT GAS  R-142B CLASS:2.1   UN NO:2517': 1,
#          '59.97 MT OF MIXED ACID OIL   PACKING IN FLEXIBAGCOUNTRY OF ORIGIN: INDONESIA': 1,
#          '59.90 MT OF MIXED ACID OIL   PACKING IN FLEXIBAGCOUNTRY OF ORIGIN: INDONESIA   CIF ULSAN': 1,
#          '15 BAGS MIXED ACID OIL SOLID  SOLID-FLB-BULK': 1,
#          '59.90 MT OF BOTTOM FATTY ACID DISTILLATE  PACKINGIN FLEXIBAG   HS CODE: 3824.99.99': 1,
#          '1,4 BDO': 2,
#          'BUTYL CARBITOL(TM) SOLVENTS': 3,
#          '84.0MTS OF PENTAERYTHRITOL 99PERCENTAGE MIN  13.6MTS OF PENTAERYTHRITOL 99PERCENTAGE MIN  CREDIT NUMO.: WHSU2070600, WHSU2008521, WHSU2338605, WHSU223': 1,
#          '80 DRUMS OF UCAR ESTER EEP 198 KG STEEL DRUM UN 3272 CLASS 3 IN THE EVENT OF AN EMERGENCY PLEASE CON* PH NO.:60-7-2528282 FAX:6072528882 E-MAIL:LAY-FU': 1,
#          'TRIPROPYLENE GLYCOL 40.06 MT CIF TAICHUNG, TAIWANPACKING: IN ISO TANK PURCHASE ORDER : 14275 EOLU82321/1423 47': 1,
#          'RHODIACID ADIPIC ACID BIG BAG 500KG CUSTOMER PO. 04115': 1,
#          'DOWANOL DPNB GLYCOL ETHER  190KG STEEL DRUM   15DRUMS COUNTRY OF ORIGIN: GERMANY  65DRUMS COUNTRYOFCY  PLEASE CONTACT THE EMERGENCY  RESPONSE NUM': 1,
#          'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3   ADDITIONAL SEAL NO: 047012/047014/047015': 1,
#          'DOWANOL* DPNB GLYCOL ETHER  190KG STEEL DRUM   COUNTRY OF ORIGIN: UNITED STATES   IN THE EVENT OF ANUMBER 8-3999-0007': 1,
#          'COMMODITY : CAPROLACTAM FLAKES  QTY : 240MT  PACKING : 25KGS IN  BAG/PALLETIZED 16MT INTO  20FT CONT4AACCG1761D1Z4  3. EMAILID INFO-AT THE RATE-CAPL': 1,
#          'PRODUCT NAME QUANTITY  BASE OIL 150N 39.40 MT  (IN2 FLEXIBAGS)  BASE OIL 600N 59.10 MT  (IN 3 FLEXIBT 19.78 MT / 150N  WHSU2009390 19.72 MT 19.82 MT': 1,
#          'NITROGEN TRIFLUORIDE ISO CONTAINER FOR ABOVE GAS HYOSUNG-OWNED ISO CONTAINER : 1TANK(20FT)  IMDG CLASS:2.2 UN NO:2451': 1,
#          'FULLY REFRIGERATED ETHYLENE': 1,
#          'D-SOL 260R 240KEROSENE PREPARATIONS': 1,
#          'PETROLEUM OILS': 2,
#          'ANIONIC ORGANIC SURFACE ACTIVE AGENTS': 1,
#          'DOW CORNING(R) 2-0408(CYCLOPLYDIMETHYLSILOXANE)': 1,
#          'ADDITIVE FOR LUBRICANTS LIQUID PARAFFIN': 1,
#          'C5 FRACTION': 5,
#          'DI ETHYLENE GLYCOL': 4,
#          'METHYLCYCLOHEXANE': 1,
#          ...})

# %%
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
type(aa18_count2)
aa18_count2[180][0]

li=[]
li2=[]

for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa_count2)):
    li2.append(aa18_count2[i][0])
li2
# Out:
# ['LUBRICATING BASE OIL',
#  'ACETIC ACID',
#  'ETHANOL (ETHYL ALCOHOL)',
#  'ASPHALT',
#  'TOLUENE',
#  'PARAXYLENE',
#  'MIXED XYLENE',
#  'PROPYLENE GLYCOL',
#  'DIMETHYL TEREPHTHALATE',
#  'ACRYLONITRILE',
#  'BENZENE',
#  'POLYMER GRADE PROPYLENE',
#  'PROPYLENE',
#  'METHYL ETHYL KETONE',
#  'PURIFIED ISOPHTHALIC ACID',
#  'ADIPIC ACID',
#  'ASPHALT 80/100 PETROLEUM BITUMEN',
#  'ISOPHTHALIC ACID',
#  'ASPHALT 60/80 PETROLEUM BITUMEN',
#  'ETHYL ALCOHOL',
#  'PARA XYLENE',
#  'DIPROPYLENE GLYCOL',
#  'LUBRICATING OIL',
#  'KEROSENE',
#  'MOLTEN SULPHUR IN BULK',
#  'ADIPONITRILE',
#  'SULFURIC ACID',
#  'ASPHALT RAS 80',
#  'ASPHALT RAS 100',
#  'BASE OIL',
#  'GAS OIL',
#  'UNCONVERTED OIL (UCO)',
#  'PAINT',
#  'C9AROMATICS',
#  'CYCLOHEXANOL',
#  'CYCLOHEXANE',
#  'THIOALCOHOLS',
#  'ACETIC ACID GLACIAL',
#  'LIQUID PARAFFIN',
#  'MOLTEN SULPHUR',
#  'ACETIC ANHYDRIDE',
#  'AH-70 SK BRAND BULK ASPHALT',
#  'CUMENE',
#  'EMPTY TANK(AHF)',
#  'DIETHANOLAMINE',
#  'DIACIDS DBA FLAKES',
#  'KEROSENE PREPARATIONS',
#  'BASE OIL (MDO-L)',
#  '3-ETHOXYPROPIONIC ACID ETHYL ESTER',
#  'N-BUTYL ACETATE',
#  'ETHYLENE DICHLORIDE (E.D.C.)',
#  'ENGINE OIL FOR AUTOMOTIVE',
#  'PROPYLENE OXIDE',
#  'SALT-BITTERN',
#  'NITRIC ACID',
#  'C5(FRACTION)',
#  'YUBASE 4 LUBRICATING BASE OIL',
#  'GASOLINE',
#  'EMPTY TANK',
#  'MIXED-XYLENE',
#  'POTASSIUM HYDROXIDE',
#  'LIGHT CYCLE OIL',
#  'GASOIL',
#  'PROPYLENE(REFINERY GRADE)',
#  'STYRENE MONOMER',
#  'ALPHA OLEFIN C8',
#  'META XYLENE',
#  'SULPHURIC ACID',
#  'BUTYL CELLOSOLVE TM SOLVENT',
#  'PHTHALIC ANHYDRIDE',
#  'PROPYLENE (CHEMICAL GRADE)',
#  'SK AH-90 ASPHALT IN BULK',
#  'NOCOLOK FLUX',
#  'MONOETHANOLAMINE',
#  'ASPHALT AH-70',
#  'ETHYLENE DIAMINE TETRA ACETIC ACID TETRASODIUMSALT',
#  'ADDITIVE FOR LUBRICANTS',
#  'TERTIARY DODECYL MERCAPTAN',
#  'SULFURIC ACID(H2SO4)',
#  'ALUMINUM HYDROXIDE',
#  'REFINERY GRADE PROPYLENE',
#  'PURIFIED TEREPHTHALIC ACID',
#  'HEXENE',
#  'TRIPROPYLENE GLYCOL',
#  'QUATERNARY AMMONIUM SALTS',
#  'COPPER STRIP',
#  'COMMODITY : PURIFIED ISOPHTHALIC ACID(PIA) QUANTITY : 20 MT * IEC : 0812008723 GSTIN : 24AAKCA2207N1RVEELABS.COM',
#  'GASOLINE MOTOR SPIRIT',
#  'VINYL ACETATE MONOMER',
#  'PYGAS',
#  'ACETONITRILE',
#  'MONO ETHYLENE GLYCOL',
#  'ASPHALT PEN 60-80',
#  'EPICHLOROHYDRIN',
#  'ASPHALT AH-70 IN BULK',
#  'PROPYLENE (POLYMER GRADE)',
#  'PETROLEUM DISTILLATES',
#  'PVC PASTE RESIN',
#  'MALEIC ANHYDRIDE',
#  'SULPHUR HEXAFLUORIDE',
#  'EPICHLOROHYDRIN (ECH)',
#  'ENGINE OIL',
#  'CARBON BLACK FEED STOCK',
#  'PALM FATTY ACID DISTILLATE',
#  'VINYL ACETATE HQ 7-9 PPM',
#  'DI PROPYLENE GLYCOL',
#  'UCAR(TM) ESTER EEP BULK UN 3272 CLASS 3',
#  'STRAIGHT ASPHALT 60/80 PETROLEUM BITUMEN',
#  'LSFO',
#  'METHYL METHACRYLATE MONOMER',
#  '2-ETHYL HEXYL ALCOHOL',
#  'LITHIUM HEXAFLUOROPHOSPHATE',
#  'BASE OIL ULTRA-S 2',
#  'PARAFFIN 150N',
#  'METHANOL',
#  'PROPYLENE (REFINERY GRADE)',
#  'STRAIGHT ASPHALT 80/100 PETROLEUM BITUMEN',
#  'ALLYL ALCOHOL',
#  'POLYMERIC MDI',
#  'LIQUID ALKANES 150N',
#  'TETRACHLOROETHYLENEPERCHLOROETHYLENE',
#  'ACETIC ANHYDRIDE IN BULK',
#  'PARAFFIN OIL',
#  'SULFURIC ACID IN BULK',
#  'VINYL ACETATE',
#  'JET FUEL',
#  'GASOIL 10PPM',
#  'BUTYL CELLOSOLVE TM SOLVENTETHYLENE GLYCOL MONOALKYL ETHERS',
#  'SODIUM HYDROSULPHITE',
#  'BASE OIL 150BS',
#  'DIISOBUTYL KETONE',
#  'N-PROPANOL',
#  'AH-90 SK BRAND BULK ASPHALT',
#  'DOWANOL TM PM GLYCOL ETHER(PROPYLENE GLYCOL MONOALKYL ETHER)',
#  'ENGINE OIL FOR MARINE USE',
#  'TETRAHYDROFURAN',
#  'ACETIC ACID IN BULK',
#  'TRANSFORMER OIL',
#  'PETROLEUM OILS AND OILS OBTAINED FROM BITUMINOUS MINERALS (O',
#  'METHYL CYCLOHEXANE',
#  'YUBASE 3 YUBASE 6 LUBRICATING BASE OIL',
#  'LUBRICATING BASE OIL AROMAX T-DAE (E)',
#  'LUBRICATING BASE OIL 60EX NEUTRAL',
#  'DER (TM) 383 LCL EPOXY RESINDIGLYCIDYL ETHER OF BISPHENOL A MARPOL',
#  'ACETONE',
#  'LCO',
#  'CYCLOHEXANONE',
#  'PROPYLENE GLYCOL USP',
#  'BRASS STRIP',
#  'DIETHYLENEGLYCOL MONOBUTYL ETHER',
#  'MONOSODIUM L-GLUTAMATE  MONOSODIUM L-GLUTAMATE',
#  '2-ETHYLHEXYL ALCOHOL',
#  'BASE OIL 500SN',
#  'BASE OIL YUBASE 4,BASE OIL YUBASE 6',
#  'SODIUM HYDRO SULPHITE 85PCT MIN',
#  'METHYL ISOBUTYL KETONE',
#  'YUBASE 4 YUBASE 6 YUBASE 4 PLUS LUBRICATING BASE OIL',
#  'UNLEADED GASOLINE MOTOR SPIRIT',
#  'DOP(DI OCTYL PHTHALATE)',
#  'NORMAL BUTANOL',
#  'BUTYL CELLOSOLVE TM SOLVENT BULK',
#  'ASPHALT AH-90',
#  'HSB 500N (DAESAN)',
#  'SK AH-70 ASPHALT IN BULK',
#  'H.B.M. (VOLATILE OIL)',
#  'NORMAL PARAFFIN',
#  'PALM ACID OIL',
#  'PERCHLOROETHYLENE FLUOROCARBON GRADE',
#  'CHLOROFORM',
#  'SULFUR',
#  '6-HEXANELACTAM',
#  'ASPHALT 80/100PETROLEUM BITUMEN',
#  'PAPI TM 27 POLYMERIC MDIPOLYMETHYLENE POLYPHENYL ISOCYANATE',
#  'TRIETHANOLAMINE',
#  'HEXENE 1',
#  'BUNKER C',
#  '10PPM GAS OIL',
#  'MONOETHANOLAMINE(MEA)',
#  'ALPHAPLUS(R) 1-TETRADECENEOLEFINS (C13 ALL ISOMERS)',
#  'ETHYLENE DICHLORIDE',
#  'ETHYLENEDIAMINE (EDA)']

# %%
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
type(aa18_count2)
aa18_count2[180][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa_count2)):
    li.append(aa_count2[i][1])
    sum+=aa_count2[i][1]
for i in range(len(aa_count2)):
    li2.append(aa_count2[i][0])
li2
# Out:
# [293100,
#  271000,
#  271019,
#  271300,
#  291521,
#  291739,
#  271114,
#  290532,
#  290550,
#  291712,
#  291411,
#  291737,
#  290949,
#  292610,
#  271320,
#  280700,
#  281111,
#  293090,
#  382319,
#  291899,
#  320890,
#  271113,
#  382499,
#  281290,
#  290260,
#  290220,
#  283325,
#  293190,
#  340319,
#  381090,
#  281830,
#  290943,
#  280800,
#  321410,
#  340300,
#  292690,
#  291736,
#  292249,
#  292390,
#  382311,
#  290129,
#  291735,
#  284700,
#  283110,
#  292212,
#  293371,
#  290230,
#  281520,
#  291714,
#  271121,
#  290240,
#  290200,
#  382370,
#  290960,
#  282690,
#  270900,
#  283329,
#  290511,
#  382490,
#  290339,
#  292242,
#  290819,
#  290219,
#  291419,
#  290122,
#  290270,
#  282700,
#  283711,
#  283324,
#  293000,
#  291512,
#  292210,
#  291030,
#  291732,
#  290542,
#  290544,
#  340290,
#  340399,
#  293379,
#  290312,
#  350610,
#  283640,
#  320417,
#  294200,
#  282619,
#  292419,
#  282751,
#  320411,
#  380610,
#  290379,
#  291539,
#  284190,
#  291632,
#  290110,
#  293499,
#  381512,
#  290321,
#  281122,
#  283220,
#  292310,
#  350699,
#  290545,
#  290243,
#  290721,
#  340490,
#  290211,
#  290531,
#  290499,
#  271012,
#  381100,
#  283630,
#  381511,
#  380893,
#  282760,
#  283620,
#  282731,
#  293399,
#  152200,
#  290612,
#  340211,
#  290512,
#  340111,
#  290250,
#  290539,
#  291720,
#  293369,
#  290941,
#  290290,
#  282510,
#  151190,
#  380991,
#  291611,
#  285000,
#  382460,
#  291631,
#  284610,
#  320300,
#  294190,
#  291439,
#  291412,
#  284020,
#  281500,
#  340212,
#  290549,
#  330499,
#  292151,
#  380891,
#  382477,
#  330410,
#  320416,
#  290300,
#  291413,
#  381519,
#  283321,
#  280200,
#  283327,
#  293211,
#  151800,
#  283010,
#  320412,
#  291612,
#  292111,
#  285210,
#  292121,
#  381400,
#  281512,
#  292213,
#  280429,
#  271099,
#  370120,
#  291639,
#  290392,
#  290121,
#  293139,
#  330510,
#  290372,
#  291614,
#  292910,
#  291550,
#  290320,
#  380899]

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *

df=pd.DataFrame({'품명':li2,'카운팅':li})
#df['품목코드']
df
#df2=df.iloc[0:20]

#sums_by_code=df2.groupby('품명').sum()
#sums_by_code
#sums_by_code.plot(kind='bar',subplots=True)
# Out:
#          품명   카운팅
# 0    293100  2219
# 1    271000   947
# 2    271019   770
# 3    271300   592
# 4    291521   222
# 5    291739   209
# 6    271114   191
# 7    290532   185
# 8    290550   169
# 9    291712   160
# 10   291411   147
# 11   291737   125
# 12   290949   115
# 13   292610    94
# 14   271320    90
# 15   280700    85
# 16   281111    74
# 17   293090    73
# 18   382319    72
# 19   291899    62
# 20   320890    43
# 21   271113    42
# 22   382499    36
# 23   281290    35
# 24   290260    35
# 25   290220    35
# 26   283325    34
# 27   293190    34
# 28   340319    30
# 29   381090    29
# ..      ...   ...
# 151  291413     1
# 152  381519     1
# 153  283321     1
# 154  280200     1
# 155  283327     1
# 156  293211     1
# 157  151800     1
# 158  283010     1
# 159  320412     1
# 160  291612     1
# 161  292111     1
# 162  285210     1
# 163  292121     1
# 164  381400     1
# 165  281512     1
# 166  292213     1
# 167  280429     1
# 168  271099     1
# 169  370120     1
# 170  291639     1
# 171  290392     1
# 172  290121     1
# 173  293139     1
# 174  330510     1
# 175  290372     1
# 176  291614     1
# 177  292910     1
# 178  291550     1
# 179  290320     1
# 180  380899     1
#
# [181 rows x 2 columns]

# %%
q=newu18[newu18['입항횟수']>=7]
q['입항횟수']
q['품목코드']

data=pd.DataFrame({'품목코드':q['품목코드'],'입항횟수':q['입항횟수'] })
data = data.sort_values(["입항횟수"], ascending=[False])
data

#이 코드는 중복 품목코드가 합쳐져서 안나와서 일단 보류
# Out:
#          품목코드  입항횟수
# 21594  271000    75
# 21593  271000    75
# 21413  271000    74
# 21141  271000    73
# 21142  271000    73
# 20915  271000    72
# 20465  271000    71
# 20181  271000    70
# 20180  271000    70
# 20024  271000    69
# 21415  290260    69
# 20025  271000    69
# 21077  290260    68
# 21076  290260    68
# 19636  271000    68
# 104    271300    68
# 105    271300    68
# 20246  292610    67
# 19442  271000    67
# 19441  271000    67
# 19158  271000    66
# 19159  271000    66
# 21457  271300    66
# 21456  271300    66
# 20902  271300    65
# 18883  271000    65
# 18884  271000    65
# 19614  290260    65
# 19613  290260    65
# 20901  271300    65
# ...       ...   ...
# 6488   290240     7
# 8660   381090     7
# 12828  291712     7
# 16165  293100     7
# 14617  271000     7
# 11840  281111     7
# 11841  271019     7
# 11842  271019     7
# 11843  292690     7
# 11844  291714     7
# 11845  291521     7
# 8819   280700     7
# 8801   293100     7
# 19047  293100     7
# 19046  293100     7
# 6426   271114     7
# 6437   271320     7
# 6438   271320     7
# 11264  291411     7
# 11263  271000     7
# 16068  293100     7
# 4522   271300     7
# 4521   271300     7
# 6457   271320     7
# 6477   290949     7
# 6478   291739     7
# 16123  293100     7
# 6479   290129     7
# 20843  291411     7
# 15486  293100     7
#
# [7841 rows x 2 columns]

# %% [markdown]
# # 08년도랑 18년도 1위부터 30위

# %% [markdown]
# # 2018

# %%
aa18=newu18[newu18['입항횟수']>=7]
aa18
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기

from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
aa18_count
#입항횟수가 7이상인 품목코드만 뽑기 

#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
type(aa18_count2)
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
    
#plot    
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *

df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']

df2=df.iloc[0:30]

sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                   카운팅
# 품목코드
# LUBRICATING BASE OIL              446
# ACETIC ACID                       236
# ETHANOL (ETHYL ALCOHOL)           172
# ASPHALT                           170
# TOLUENE                           157
# PARAXYLENE                        145
# MIXED XYLENE                      139
# PROPYLENE GLYCOL                  138
# DIMETHYL TEREPHTHALATE            119
# ACRYLONITRILE                     116
# BENZENE                           112
# POLYMER GRADE PROPYLENE           108
# PROPYLENE                          96
# METHYL ETHYL KETONE                95
# PURIFIED ISOPHTHALIC ACID          92
# ADIPIC ACID                        90
# ASPHALT 80/100 PETROLEUM BITUMEN   80
# ISOPHTHALIC ACID                   73
# ASPHALT 60/80 PETROLEUM BITUMEN    71
# ETHYL ALCOHOL                      70
# PARA XYLENE                        70
# DIPROPYLENE GLYCOL                 67
# LUBRICATING OIL                    62
# KEROSENE                           60
# MOLTEN SULPHUR IN BULK             58
# ADIPONITRILE                       58
# SULFURIC ACID                      55
# ASPHALT RAS 80                     53
# ASPHALT RAS 100                    51
# BASE OIL                           50

# %%
# 2017

# %%
aa18=newu17[newu17['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                   카운팅
# 품목코드
# LUBRICATING BASE OIL              502
# ASPHALT                           253
# ACETIC ACID                       240
# PARAXYLENE                        172
# MIXED XYLENE                      170
# ETHANOL (ETHYL ALCOHOL)           153
# TOLUENE                           141
# PURIFIED ISOPHTHALIC ACID         128
# ADIPIC ACID                       127
# BENZENE                           122
# POLYMER GRADE PROPYLENE           115
# STYRENE MONOMER                   102
# ACRYLONITRILE                     100
# BASE OIL                          100
# ETHYL ALCOHOL                      96
# ASPHALT 80/100 PETROLEUM BITUMEN   95
# MOLTEN SULPHUR                     88
# PROPYLENE                          80
# METHYL ETHYL KETONE                77
# ASPHALT 60/80 PETROLEUM BITUMEN    75
# LIQUID PARAFFIN                    72
# ADIPONITRILE                       72
# C9AROMATICS                        64
# GAS OIL                            63
# ASPHALT RAS 80                     62
# ASPHALT AH-70                      60
# DIMETHYL TEREPHTHALATE             57
# EMPTY TANK                         57
# CUMENE                             54
# ASPHALT RAS 100                    50

# %%
# 2016

# %%
aa18=newu16[newu16['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                   카운팅
# 품목코드
# LUBRICATING BASE OIL              319
# ASPHALT                           206
# ETHANOL (ETHYL ALCOHOL)           152
# MIXED XYLENE                      135
# POLYMER GRADE PROPYLENE           134
# PARAXYLENE                        134
# AUTOMATIC TRANSMISSION FLUID      130
# PURIFIED ISOPHTHALIC ACID         122
# ACETIC ACID                       121
# ADIPIC ACID                       121
# TOLUENE                           119
# PROPYLENE                         105
# BASE OIL                          104
# MOLTEN SULPHUR                     98
# SULFURIC ACID                      96
# ACRYLONITRILE                      95
# ASPHALT 80/100 PETROLEUM BITUMEN   83
# LIQUID PARAFFIN                    72
# BENZENE                            70
# METHYL ETHYL KETONE                67
# ASPHALT AH-70                      66
# STYRENE MONOMER                    64
# ISOPHTHALIC ACID                   60
# C9AROMATICS                        60
# ASPHALT 60/80 PETROLEUM BITUMEN    56
# DIMETHYL TEREPHTHALATE             56
# PROCESS OIL                        53
# ASPHALT RAS 80                     53
# KEROSENE                           47
# ASPHALT AH-90                      47

# %%
# 2015

# %%
aa18=newu15[newu15['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                   카운팅
# 품목코드
# ASPHALT                           220
# ETHANOL (ETHYL ALCOHOL)           168
# TOLUENE                           148
# LUBRICATING BASE OIL              135
# MIXED XYLENE                      130
# BENZENE                           128
# PARAXYLENE                        120
# ISOPHTHALIC ACID                  112
# ACRYLONITRILE                      99
# MOLTEN SULPHUR                     98
# SULFURIC ACID                      88
# ADIPIC ACID                        88
# STYRENE MONOMER                    86
# PROPYLENE                          61
# C9AROMATICS                        61
# LOW SULPHUR FUEL OIL               56
# PURIFIED ISOPHTHALIC ACID          55
# METHYL ETHYL KETONE                55
# ASPHALT 80/100 PETROLEUM BITUMEN   55
# ASPHALT AH-70                      54
# PROPYLENE (CHEMICAL GRADE)         52
# MIXED-XYLENE                       50
# ASPHALT 60/80 PETROLEUM BITUMEN    50
# BASE OIL                           49
# SODIUM HYDROSULPHITE               48
# ASPHALT RAS 80                     46
# PROPYLENE OXIDE                    45
# PROPYLENE GLYCOL                   44
# POLYMER GRADE PROPYLENE            43
# ACETIC ACID                        42

# %%
# 2014

# %%
aa18=newu14[newu14['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                             카운팅
# 품목코드
# ASPHALT                     273
# TOLUENE                     144
# MIXED XYLENE                143
# PARAXYLENE                  142
# ETHANOL (ETHYL ALCOHOL)     142
# ACRYLONITRILE               141
# STYRENE MONOMER             119
# PROPYLENE (CHEMICAL GRADE)   95
# SULFURIC ACID                83
# CUTTING OIL PREPARATIONS     73
# ASPHALT AH-70                70
# ISOPHTHALIC ACID             69
# BENZENE                      68
# PROPYLENE                    68
# ASPHALT RAS 80               66
# MOLTEN SULPHUR               65
# MIXED-XYLENE                 63
# METHYL ETHYL KETONE          59
# LOW SULPHUR FUEL OIL         55
# BASE OIL                     54
# LOW SULFUR FUEL OIL          53
# KEROSENE                     52
# ASPHALT RAS 100              52
# LSFO                         51
# PROPYLENE OXIDE              51
# ADIPIC ACID                  43
# UNCONVERTED OIL (UCO)        41
# MONOETHYLENE GLYCOL          40
# CYCLOHEXANOL                 35
# ASPHALT 60-80 PENETRATION    35

# %%
# 2013

# %%
aa18=newu13[newu13['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                             카운팅
# 품목코드
# ASPHALT                     265
# PARAXYLENE                  222
# ACRYLONITRILE               191
# PROPYLENE (CHEMICAL GRADE)  122
# ETHANOL (ETHYL ALCOHOL)     121
# STYRENE MONOMER             113
# MIXED XYLENE                 98
# PROPYLENE                    92
# TOLUENE                      85
# BENZENE                      80
# LSFO                         77
# NEODOL 25-3                  71
# LOW SULPHUR FUEL OIL         65
# LOW SULFUR FUEL OIL          62
# ASPHALT AH-70                57
# ASPHALT RAS 80               56
# SULFURIC ACID                55
# MOLTEN SULPHUR               51
# PROPYLENE OXIDE              48
# 1,3 BUTADIENE                46
# KEROSENE                     45
# PARA XYLENE                  39
# CYCLOHEXANOL                 39
# 98PCT NITRIC ACID            39
# METHYL ETHYL KETONE          37
# LUBRICATING BASE OIL         37
# BASE OIL                     36
# FERMENTATION ETHYL ALCOHOL   35
# ASPHALT RAS 100              33
# NEODOL 25-9                  32

# %%
# 2012

# %%
aa18=newu12[newu12['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                   카운팅
# 품목코드
# PARAXYLENE                        320
# ASPHALT                           226
# ACRYLONITRILE                     149
# LOW SULPHUR FUEL OIL              107
# ETHANOL (ETHYL ALCOHOL)           100
# LOW SULFUR FUEL OIL                92
# MIXED XYLENE                       92
# STYRENE MONOMER                    75
# TOLUENE                            73
# GASOLINE                           69
# PROPYLENE                          68
# BENZENE                            64
# SULFURIC ACID                      50
# MOLTEN SULPHUR                     49
# YUBASE 4                           49
# ASPHALT 60/80                      49
# ASPHALT RAS 80                     48
# LUBRICATING BASE OIL               44
# PROPYLENE (CHEMICAL GRADE)         42
# 98PCT NITRIC ACID                  42
# ASPHALT RAS 100                    39
# CYCLOHEXANOL                       38
# PROPYLENE OXIDE                    35
# FERMENTATION ETHYL ALCOHOL         35
# YUBASE 4 PLUS                      35
# METHYL ETHYL KETONE                34
# SAFOL 23 (C12/13 ALCOHOL)          33
# KEROSENE                           31
# ASPHALT 80/100                     31
# PURIFIED TEREPHTHALIC ACID (PTA)   29

# %%
# 2011

# %%
aa18=newu11[newu11['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                      카운팅
# 품목코드
# ASPHALT                              263
# PARAXYLENE                           203
# ACRYLONITRILE                        142
# STYRENE MONOMER                      121
# MIXED XYLENE                         108
# PURIFIED TEREPHTHALIC ACID (PTA)     100
# TOLUENE                               96
# ETHANOL (ETHYL ALCOHOL)               91
# YUBASE 4                              85
# GASOLINE                              81
# SULFURIC ACID                         69
# PROPYLENE                             69
# ASPHALT 60/80                         60
# BENZENE                               57
# ASPHALT RAS 80                        55
# PHENOL                                54
# KEROSENE                              53
# MOLTEN SULPHUR                        47
# ASPHALT RAS 100                       45
# PROPYLENE (CHEMICAL GRADE)            42
# FERMENTATION ETHYL ALCOHOL            41
# LOW SULFUR FUEL OIL                   39
# CYCLOHEXANOL                          38
# GAS OIL                               35
# ASPHALT FOR ROAD CONSTRUCTION 60/80   31
# FERMENTATION CRUDE ETHYL ALCOHOL      31
# ACETONE                               29
# ETHYLENE                              29
# CUMENE                                26
# NEODOL 25-3                           25

# %%
# 2010

# %%
aa18=newu10[newu10['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                   카운팅
# 품목코드
# ASPHALT                           273
# ACRYLONITRILE                     133
# STYRENE MONOMER                   114
# YUBASE 4                          111
# MIXED XYLENE                      104
# PURIFIED TEREPHTHALIC ACID (PTA)   93
# PARAXYLENE                         85
# METHYL ETHYL KETONE                70
# SULFURIC ACID                      69
# PROPYLENE                          68
# TOLUENE                            67
# ETHANOL (ETHYL ALCOHOL)            63
# GASOLINE                           54
# PHENOL                             53
# ASPHALT RAS 80                     51
# ASPHALT RAS 100                    46
# BENZENE                            45
# CYCLOHEXANOL                       44
# KEROSENE                           38
# ASPHALT 60 80                      37
# PROPYLENE (CHEMICAL GRADE)         36
# MOLTEN SULPHUR                     34
# FERMENTATION ETHYL ALCOHOL         31
# DOWANOL PM GLYCOL ETHER            31
# PROPYLENE (REFINERY GRADE)         30
# YUBASE 6                           30
# ETHYLENE                           27
# VINYL ACETATE                      24
# YUBASE 3                           23
# NEODENE 6 XHP (HEXENE-1)           22

# %%
# 2009

# %%
aa18=newu9[newu9['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                   카운팅
# 품목코드
# MIXED XYLENE                      142
# ASPHALT                           116
# SULFURIC ACID                     115
# TOLUENE                           107
# YUBASE 4                          105
# PARAXYLENE                         94
# STYRENE MONOMER                    84
# ACRYLONITRILE                      81
# CYCLOHEXANOL                       81
# METHYL ETHYL KETONE                75
# ETHANOL (ETHYL ALCOHOL)            54
# GASOLINE                           53
# BENZENE                            50
# ASPHALT RAS 80                     48
# PROPYLENE                          44
# SULPHURIC ACID                     42
# ASPHALT RAS 100                    41
# MOLTEN SULPHUR                     37
# ETHYLENE                           31
# PURIFIED TEREPHTHALIC ACID(PTA)    30
# YUBASE 6                           28
# PURIFIED TEREPHTHALIC ACID (PTA)   27
# C4 RAFFINATE 1                     26
# VINYL ACETATE MONOMER              24
# ASPHALT 60 80                      22
# PROPYLENE (REFINERY GRADE)         21
# NEODOL 25-3                        20
# BULK ACETIC ACID                   19
# ETHANOL/ALCOHOL                    18
# ACETIC ACID                        17

# %% [markdown]
# # 2008

# %%
aa18=newu8[newu8['입항횟수']>=7]
#입항횟수 평균이 7 인것을 감안해서 7이상만 뽑기
from collections import Counter
aa18_count=Counter(aa18['품명'])
#aa18_count=Counter(aa18['품목코드'])
#입항횟수가 7이상인 품목코드만 뽑기 
#입항횟수가 7이상인 품목코드를 카운팅하여서 내림차순으로 정리 
aa18_count2=sorted(aa18_count.items(), key=lambda x: x[1], reverse=True)
#aa_count2[:]
aa18_count2[len(aa18_count2)-1][1]
#len(aa_count2)
li=[]
li2=[]
sum=0
#품목코드 카운팅 수 평균 계산 
for i in range(len(aa18_count2)):
    li.append(aa18_count2[i][1])
    sum+=aa18_count2[i][1]
for i in range(len(aa18_count2)):
    li2.append(aa18_count2[i][0])
#plot    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine
from plotnine import *
df=pd.DataFrame({'품목코드':li2,'카운팅':li})
#df['품목코드']
df2=df.iloc[0:30]
sums_by_code=df2.groupby('품목코드').sum()

#sums_by_code.plot(kind='bar',subplots=True)
sums_by_code.sort_values(["카운팅"], ascending=[False])
# Out:
#                                    카운팅
# 품목코드
# MIXED XYLENE                       175
# PARAXYLENE                         141
# YUBASE 4                           117
# ASPHALT                             95
# METHYL ETHYL KETONE                 84
# ACRYLONITRILE                       79
# STYRENE MONOMER                     74
# BENZENE                             74
# SULFURIC ACID                       65
# CYCLOHEXANOL                        64
# TOLUENE                             63
# ASPHALT 60/80                       63
# ETHANOL (ETHYL ALCOHOL)             59
# PROPYLENE                           53
# ASPHALT RAS 80                      49
# GASOLINE                            48
# ASPHALT RAS 100                     44
# PURIFIED ISOPHTHALIC ACID           42
# sulfuric acid                       38
# YUBASE 6                            35
# MOLTEN SULPHUR                      31
# NEODOL 25-3                         26
# ACETIC ACID                         25
# YUBASE 8                            24
# PHENOL                              23
# VINYL ACETATE MONOMER               23
# ETHYLENE                            22
# CHLOROFORM                          20
# LUBE BASE OIL 500 SOLVENT NEUTRAL   19
# EPICHLOROHYDRIN                     19
